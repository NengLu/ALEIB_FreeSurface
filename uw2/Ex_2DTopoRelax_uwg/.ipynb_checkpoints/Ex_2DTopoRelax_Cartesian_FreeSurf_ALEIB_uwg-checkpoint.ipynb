# %%
import underworld as uw
import math
from underworld import function as fn
import numpy as np
import os

from underworld import UWGeodynamics as GEO
u = GEO.UnitRegistry
ndim = GEO.non_dimensionalise
dimen = GEO.dimensionalise

comm = uw.mpi.comm
rank = uw.mpi.rank
size = uw.mpi.size

from _freesurface_ALEIB import FreeSurfaceProcessor_ALEIB
# Out:
# loaded rc file /home/nl/anaconda3/envs/uw2/lib/python3.11/site-packages/underworld/UWGeodynamics/uwgeo-data/uwgeodynamicsrc

# %%
# solver parameters
GEO.rcParams["initial.nonlinear.tolerance"] = 1e-3
GEO.rcParams['initial.nonlinear.max.iterations'] = 100
GEO.rcParams["nonlinear.tolerance"] = 1e-3
GEO.rcParams['nonlinear.max.iterations'] = 100
GEO.rcParams["popcontrol.particles.per.cell.2D"] = 16
GEO.rcParams["swarm.particles.per.cell.2D"] = 16
GEO.rcParams["surface.pressure.normalization"] = True
GEO.rcParams["pressure.smoothing"] = True
GEO.rcParams["popcontrol.split.threshold"] = 0.1

# %%
# scaling 3: vel
half_rate = 1.0 * u.centimeter / u.year
model_length = 500. * u.kilometer
gravity = 9.81 * u.meter / u.second**2
bodyforce = 3300 * u.kilogram / u.metre**3 *gravity 

KL = model_length
Kt = KL / half_rate
KM = bodyforce * KL**2 * Kt**2

GEO.scaling_coefficients["[length]"] = KL
GEO.scaling_coefficients["[time]"] = Kt
GEO.scaling_coefficients["[mass]"]= KM

# %%
xmin, xmax = ndim(-250 * u.kilometer), ndim(250 * u.kilometer)
ymin, ymax = ndim(-500 * u.kilometer), ndim(100 * u.kilometer)
yint = 0.
 
dy = ndim(500 * u.kilometer)/50
dx = dy
xRes,yRes = int((xmax-xmin)/dx),int((ymax-ymin)/dy)
yResa,yResb =int((ymax-yint)/dy),int((yint-ymin)/dy)

#tRatio =  int(sys.argv[1])
tRatio = 100
save_every = 1
use_fssa = False
if use_fssa:
    outputPath = "op_Ex_2DTopoRelax_FreeSurf_ALEIB_withFSSA0.5_yres{:n}_tRatio{:n}_Swarm_uwg".format(yRes,tRatio)
    save_every = 1
else:
    outputPath = "op_Ex_2DTopoRelax_FreeSurf_ALEIB_noFSSA_yres{:n}_tRatio{:n}_Swarm_uwg".format(yRes,tRatio)
    save_every = 5

# %%
Model = GEO.Model(elementRes=(xRes, yRes),
                  minCoord=(xmin,ymin),
                  maxCoord=(xmax, ymax),
                  gravity=(0.0, -gravity),
                  periodic=(True, False))
Model.outputDir= outputPath
Model.minStrainRate = 1e-18 / u.second
# Out:
# 	Global element size: 50x60
# 	Local offset of rank 0: 0x0
# 	Local range of rank 0: 50x60
# In func WeightsCalculator_CalculateAll(): for swarm "MSUUDH1T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "MSUUDH1T__swarm"

# %%
wRatio = 1
D = np.abs(ymin)
Lambda = D/wRatio
k = 2.0 * np.pi / Lambda
mu0 = ndim(1e21  * u.pascal * u.second)
g = ndim(gravity)
rho0 = ndim(3300* u.kilogram / u.metre**3)
drho = rho0-0.
w_m = ndim(10*u.kilometer)

tau0 = 2*k*mu0/drho/g
tau = (D*k+np.sinh(D*k)*np.cosh(D*k))/(np.sinh(D*k)**2)*tau0

def perturbation(x):
    return w_m * np.cos(2.*np.pi*(x)/Lambda)

fn_coord = fn.input()
deform_fn = w_m * fn.math.cos(2.*np.pi*fn_coord[0]/Lambda)

# def get_analytical(x0,load_time):
#     #tau = (D*k+np.sinh(D*k)*np.cosh(D*k))/(np.sinh(D*k)**2)*tau0
#     #A = -F0/k/tau0
#     #B = -F0/k/tau
#     #C = F0/tau
#     #E = F0/tau/np.tanh(D*k)
#     #phi = np.sin(k*x)*np.exp(-tmax/tau)*(A*np.sinh(k*z)+B*np.cosh(k*z)+C*z*np.sinh(k*z)+E*z*np.cosh(k*z))
#     w = w_m*np.exp(-load_time/tau)
#     return w

max_time =  tau*4
dt_set = tau/tRatio

# %%
# if size == 1:
#     import underworld.visualisation as vis
    
#     Fig = vis.Figure(resolution=(500,500),rulers=True,margin = 100)
#     Fig.Mesh(Model.mesh)
#     Fig.show()
# Out:
# <img src='data:image/png;base64,...'>

# %%
D_ib = yint
axis_ib = np.where((Model.mesh.data[:,1]<=D_ib+dy/4)&(Model.mesh.data[:,1]>=D_ib-dy/4))
Sets_ib = Model.mesh.specialSets["Empty"]
for index in axis_ib:
    Sets_ib.add(index)

minCoord = tuple([GEO.nd(val) for val in Model.minCoord])
maxCoord = tuple([GEO.nd(val) for val in Model.maxCoord])

init_mesh = uw.mesh.FeMesh_Cartesian(elementType=Model.elementType,
                                    elementRes=Model.elementRes,
                                    minCoord=minCoord,
                                    maxCoord=maxCoord,
                                    periodic=Model.periodic)

TField = init_mesh.add_variable(nodeDofCount=1)
TField.data[:, 0] = init_mesh.data[:, 1].copy()

top = Model.top_wall
bottom = Model.bottom_wall
conditions = uw.conditions.DirichletCondition(variable=TField,indexSetsPerDof=(top + bottom+Sets_ib,))
system = uw.systems.SteadyStateHeat(
    temperatureField=TField,
    fn_diffusivity=1.0,
    conditions=conditions)
solver = uw.systems.Solver(system)

TField.data[axis_ib, 0] = perturbation(init_mesh.data[axis_ib,0])  

solver.solve()
with Model.mesh.deform_mesh():
     Model.mesh.data[:, -1] = TField.data[:, 0].copy()
# Out:
# 	Global element size: 50x60
# 	Local offset of rank 0: 0x0
# 	Local range of rank 0: 50x60
# Linear solver (ZYRAALA1__system-execute)
# Linear solver (ZYRAALA1__system-execute), solution time 4.103798e-03 (secs)

# %%
# if size == 1:
#     Fig = vis.Figure(resolution=(500,500),rulers=True,margin = 20)
#     Fig.Mesh(Model.mesh)
#     Fig.show()
#     Fig.save('mesh0.png')
# Out:
# <img src='data:image/png;base64,...'>

# %%
from underworld.swarm import Swarm
from collections import OrderedDict
Model.swarm_variables = OrderedDict()
Model.swarm = Swarm(mesh=Model.mesh, particleEscape=True)
Model.swarm.allow_parallel_nn = True
if Model.mesh.dim == 2:
    particlesPerCell = GEO.rcParams["swarm.particles.per.cell.2D"]
else:
    particlesPerCell = GEO.rcParams["swarm.particles.per.cell.3D"]
Model._swarmLayout = uw.swarm.layouts.PerCellSpaceFillerLayout(
    swarm=Model.swarm,
    particlesPerCell=particlesPerCell)

Model.swarm.populate_using_layout(layout=Model._swarmLayout)
Model._initialize()
# Out:
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"

# %%
materialAShape = fn_coord[1] > deform_fn #GEO.shapes.Layer(top=Model.top, bottom=Model.bottom)
materialMShape = fn_coord[1] <= deform_fn

materialA = Model.add_material(name="Air", shape=materialAShape)
materialM = Model.add_material(name="Mantle", shape=materialMShape)

# %%
# if uw.mpi.rank == 0:
#     from underworld import visualisation as vis
#     fig_res = (500,500)

#     Fig = vis.Figure(resolution=fig_res,rulers=False,margin = 20,rulerticks=7,quality=2,clipmap=False) 
#     Fig.Points(Model.swarm, Model.materialField,fn_size=2.0,discrete=True,colourBar=True,colours='blue orange')
#     Fig.Mesh(Model.mesh)
#     Fig.show()
#     Fig.save("Modelsetup.png")
# Out:
# <img src='data:image/png;base64,...'>

# %%
# Model.maxViscosity = 1e21 * u.pascal * u.second
# Model.minViscosity = 1e18 * u.pascal * u.second

materialA.viscosity = 1e18 * u.pascal * u.second
materialM.viscosity = 1e21 * u.pascal * u.second

materialA.density = 0.
materialM.density = 3300 * u.kilogram / u.metre**3

# %%
Model.set_velocityBCs(left=[0.,None],right=[0,None],bottom=[0.,0.], top=[None, 0.])

Model.init_model()

Model.solver.set_inner_method("mumps")
Model.solver.set_penalty(1e3)
# Out:
# /home/nl/anaconda3/envs/uw2/lib/python3.11/site-packages/underworld/UWGeodynamics/_model.py:1595: UserWarning: Skipping the steady state calculation: No diffusivity variable defined on Model
#   warnings.warn("Skipping the steady state calculation: No diffusivity variable defined on Model")

# %%
Model._freeSurface = True
Model.inter_wall = Sets_ib
Model._freeSurface = FreeSurfaceProcessor_ALEIB(Model)
# Out:
# 	Global element size: 50x60
# 	Local offset of rank 0: 0x0
# 	Local range of rank 0: 50x60

# %%
if use_fssa:
    Model._fssa_factor = 0.5

# %%
max_time = dimen(tau*4,u.kiloyear)
dt_set = dimen(tau/tRatio,u.kiloyear)
checkpoint_interval = dt_set*save_every 

Model.run_for(max_time, checkpoint_interval=checkpoint_interval,dt=dt_set)
# Out:
# Options:  -Q22_pc_type gkgdiag -force_correction True -ksp_type bsscr -pc_type none -ksp_k2_type NULL -rescale_equations False -remove_constant_pressure_null_space False -change_backsolve False -change_A11rhspresolve False -restore_K False -A11_ksp_type preonly -A11_pc_type lu -A11_pc_factor_mat_solver_type mumps -scr_ksp_type fgmres -scr_ksp_rtol 1e-05 -A11_mg_active False
# Linear solver (WY9ZYSO6__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001826 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.001041 secs / 1 its
#   Pressure Solve:         = 0.005775 secs / 6 its
#   Final V Solve:          = 0.00112 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.044647 seconds
#
# Linear solver (WY9ZYSO6__system-execute), solution time 4.569351e-02 (secs)
# Time Integration
# 	2nd order:                 ZVOVQBBF__integrand -    0.0225 [min] /    0.0225 [max] (secs)
# Time Integration - 0.0225372 [min] / 0.0225372 [max] (secs)
# Linear solver (S6NKT5BK__system-execute)
# Linear solver (S6NKT5BK__system-execute), solution time 1.380946e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# Step:     1 Model Time:  246.0 year dt:  246.0 year (2025-05-21 13:56:54)
# Linear solver (WY9ZYSO6__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001432 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.001005 secs / 1 its
#   Pressure Solve:         = 0.005162 secs / 6 its
#   Final V Solve:          = 0.001202 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.033127 seconds
#
# Linear solver (WY9ZYSO6__system-execute), solution time 3.336333e-02 (secs)
# Time Integration
# 	2nd order:                 ZVOVQBBF__integrand -    0.0244 [min] /    0.0244 [max] (secs)
# Time Integration - 0.0244119 [min] / 0.0244119 [max] (secs)
# Linear solver (S6NKT5BK__system-execute)
# Linear solver (S6NKT5BK__system-execute), solution time 1.462366e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# Step:     2 Model Time:  492.1 year dt:  246.0 year (2025-05-21 13:56:54)
# Linear solver (WY9ZYSO6__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001645 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0009961 secs / 1 its
#   Pressure Solve:         = 0.003816 secs / 6 its
#   Final V Solve:          = 0.001075 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.032912 seconds
#
# Linear solver (WY9ZYSO6__system-execute), solution time 3.311941e-02 (secs)
# Time Integration
# 	2nd order:                 ZVOVQBBF__integrand -    0.0232 [min] /    0.0232 [max] (secs)
# Time Integration - 0.0232754 [min] / 0.0232754 [max] (secs)
# Linear solver (S6NKT5BK__system-execute)
# Linear solver (S6NKT5BK__system-execute), solution time 1.317884e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# Step:     3 Model Time:  738.1 year dt:  246.0 year (2025-05-21 13:56:54)
# Linear solver (WY9ZYSO6__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001438 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0008285 secs / 1 its
#   Pressure Solve:         = 0.006012 secs / 6 its
#   Final V Solve:          = 0.0004928 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.031182 seconds
#
# Linear solver (WY9ZYSO6__system-execute), solution time 3.139731e-02 (secs)
# Time Integration
# 	2nd order:                 ZVOVQBBF__integrand -    0.0226 [min] /    0.0226 [max] (secs)
# Time Integration - 0.0226211 [min] / 0.0226211 [max] (secs)
# Linear solver (S6NKT5BK__system-execute)
# Linear solver (S6NKT5BK__system-execute), solution time 1.296997e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# Step:     4 Model Time:  984.1 year dt:  246.0 year (2025-05-21 13:56:55)
# Linear solver (WY9ZYSO6__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001450 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.001031 secs / 1 its
#   Pressure Solve:         = 0.004648 secs / 5 its
#   Final V Solve:          = 0.0007144 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.031300 seconds
#
# Linear solver (WY9ZYSO6__system-execute), solution time 3.150043e-02 (secs)
# Time Integration
# 	2nd order:                 ZVOVQBBF__integrand -    0.0252 [min] /    0.0252 [max] (secs)
# Time Integration - 0.0251843 [min] / 0.0251843 [max] (secs)
# Linear solver (S6NKT5BK__system-execute)
# Linear solver (S6NKT5BK__system-execute), solution time 1.559608e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# Step:     5 Model Time: 1230.2 year dt:  246.0 year (2025-05-21 13:56:56)
# Linear solver (WY9ZYSO6__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001417 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.001103 secs / 1 its
#   Pressure Solve:         = 0.006161 secs / 5 its
#   Final V Solve:          = 0.001001 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.035223 seconds
#
# Linear solver (WY9ZYSO6__system-execute), solution time 3.542316e-02 (secs)
# Time Integration
# 	2nd order:                 ZVOVQBBF__integrand -    0.0228 [min] /    0.0228 [max] (secs)
# Time Integration - 0.0228188 [min] / 0.0228188 [max] (secs)
# Linear solver (S6NKT5BK__system-execute)
# Linear solver (S6NKT5BK__system-execute), solution time 1.380195e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# Step:     6 Model Time: 1476.2 year dt:  246.0 year (2025-05-21 13:56:56)
# Linear solver (WY9ZYSO6__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001496 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.00106 secs / 1 its
#   Pressure Solve:         = 0.006065 secs / 5 its
#   Final V Solve:          = 0.001101 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.034213 seconds
#
# Linear solver (WY9ZYSO6__system-execute), solution time 3.441694e-02 (secs)
# Time Integration
# 	2nd order:                 ZVOVQBBF__integrand -    0.0231 [min] /    0.0231 [max] (secs)
# Time Integration - 0.0231337 [min] / 0.0231337 [max] (secs)
# Linear solver (S6NKT5BK__system-execute)
# Linear solver (S6NKT5BK__system-execute), solution time 1.396659e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# Step:     7 Model Time: 1722.2 year dt:  246.0 year (2025-05-21 13:56:56)
# Linear solver (WY9ZYSO6__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001461 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.001222 secs / 1 its
#   Pressure Solve:         = 0.003201 secs / 5 its
#   Final V Solve:          = 0.001359 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.029497 seconds
#
# Linear solver (WY9ZYSO6__system-execute), solution time 2.972977e-02 (secs)
# Time Integration
# 	2nd order:                 ZVOVQBBF__integrand -    0.0250 [min] /    0.0250 [max] (secs)
# Time Integration - 0.0249927 [min] / 0.0249927 [max] (secs)
# Linear solver (S6NKT5BK__system-execute)
# Linear solver (S6NKT5BK__system-execute), solution time 1.568333e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# Step:     8 Model Time: 1968.3 year dt:  246.0 year (2025-05-21 13:56:57)
# Linear solver (WY9ZYSO6__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001641 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0007153 secs / 1 its
#   Pressure Solve:         = 0.005018 secs / 5 its
#   Final V Solve:          = 0.001493 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.032563 seconds
#
# Linear solver (WY9ZYSO6__system-execute), solution time 3.277626e-02 (secs)
# Time Integration
# 	2nd order:                 ZVOVQBBF__integrand -    0.0240 [min] /    0.0240 [max] (secs)
# Time Integration - 0.0240695 [min] / 0.0240695 [max] (secs)
# Linear solver (S6NKT5BK__system-execute)
# Linear solver (S6NKT5BK__system-execute), solution time 1.520856e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# Step:     9 Model Time: 2214.3 year dt:  246.0 year (2025-05-21 13:56:57)
# Linear solver (WY9ZYSO6__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001662 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0009607 secs / 1 its
#   Pressure Solve:         = 0.00491 secs / 5 its
#   Final V Solve:          = 0.0009967 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.034577 seconds
#
# Linear solver (WY9ZYSO6__system-execute), solution time 3.483012e-02 (secs)
# Time Integration
# 	2nd order:                 ZVOVQBBF__integrand -    0.0234 [min] /    0.0234 [max] (secs)
# Time Integration - 0.0234642 [min] / 0.0234642 [max] (secs)
# Linear solver (S6NKT5BK__system-execute)
# Linear solver (S6NKT5BK__system-execute), solution time 1.351621e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# Step:    10 Model Time: 2460.3 year dt:  246.0 year (2025-05-21 13:56:58)
# Linear solver (WY9ZYSO6__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001477 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.001312 secs / 1 its
#   Pressure Solve:         = 0.005543 secs / 5 its
#   Final V Solve:          = 0.0009859 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.032952 seconds
#
# Linear solver (WY9ZYSO6__system-execute), solution time 3.318679e-02 (secs)
# Time Integration
# 	2nd order:                 ZVOVQBBF__integrand -    0.0247 [min] /    0.0247 [max] (secs)
# Time Integration - 0.0247717 [min] / 0.0247717 [max] (secs)
# Linear solver (S6NKT5BK__system-execute)
# Linear solver (S6NKT5BK__system-execute), solution time 1.466026e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# Step:    11 Model Time: 2706.4 year dt:  246.0 year (2025-05-21 13:56:58)
# Linear solver (WY9ZYSO6__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001615 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0008756 secs / 1 its
#   Pressure Solve:         = 0.006257 secs / 5 its
#   Final V Solve:          = 0.001005 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.033251 seconds
#
# Linear solver (WY9ZYSO6__system-execute), solution time 3.348111e-02 (secs)
# Time Integration
# 	2nd order:                 ZVOVQBBF__integrand -    0.0234 [min] /    0.0234 [max] (secs)
# Time Integration - 0.0234402 [min] / 0.0234402 [max] (secs)
# Linear solver (S6NKT5BK__system-execute)
# Linear solver (S6NKT5BK__system-execute), solution time 1.379327e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# Step:    12 Model Time: 2952.4 year dt:  246.0 year (2025-05-21 13:56:58)
# Linear solver (WY9ZYSO6__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001439 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0006373 secs / 1 its
#   Pressure Solve:         = 0.004474 secs / 5 its
#   Final V Solve:          = 0.0009931 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.030169 seconds
#
# Linear solver (WY9ZYSO6__system-execute), solution time 3.039766e-02 (secs)
# Time Integration
# 	2nd order:                 ZVOVQBBF__integrand -    0.0231 [min] /    0.0231 [max] (secs)
# Time Integration - 0.0230893 [min] / 0.0230893 [max] (secs)
# Linear solver (S6NKT5BK__system-execute)
# Linear solver (S6NKT5BK__system-execute), solution time 1.310240e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# Step:    13 Model Time: 3198.4 year dt:  246.0 year (2025-05-21 13:56:59)
# Linear solver (WY9ZYSO6__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001418 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0009179 secs / 1 its
#   Pressure Solve:         = 0.002962 secs / 5 its
#   Final V Solve:          = 0.0004951 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.028828 seconds
#
# Linear solver (WY9ZYSO6__system-execute), solution time 2.901433e-02 (secs)
# Time Integration
# 	2nd order:                 ZVOVQBBF__integrand -    0.0252 [min] /    0.0252 [max] (secs)
# Time Integration - 0.0252531 [min] / 0.0252531 [max] (secs)
# Linear solver (S6NKT5BK__system-execute)
# Linear solver (S6NKT5BK__system-execute), solution time 1.429037e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# Step:    14 Model Time: 3444.5 year dt:  246.0 year (2025-05-21 13:56:59)
# Linear solver (WY9ZYSO6__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.002309 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0006702 secs / 1 its
#   Pressure Solve:         = 0.003385 secs / 5 its
#   Final V Solve:          = 0.0005003 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.035179 seconds
#
# Linear solver (WY9ZYSO6__system-execute), solution time 3.552840e-02 (secs)
# Time Integration
# 	2nd order:                 ZVOVQBBF__integrand -    0.0258 [min] /    0.0258 [max] (secs)
# Time Integration - 0.0257869 [min] / 0.0257869 [max] (secs)
# Linear solver (S6NKT5BK__system-execute)
# Linear solver (S6NKT5BK__system-execute), solution time 1.414211e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# Step:    15 Model Time: 3690.5 year dt:  246.0 year (2025-05-21 13:57:00)
# Linear solver (WY9ZYSO6__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001426 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0009578 secs / 1 its
#   Pressure Solve:         = 0.005599 secs / 5 its
#   Final V Solve:          = 0.001009 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.033056 seconds
#
# Linear solver (WY9ZYSO6__system-execute), solution time 3.326195e-02 (secs)
# Time Integration
# 	2nd order:                 ZVOVQBBF__integrand -    0.0250 [min] /    0.0250 [max] (secs)
# Time Integration - 0.0250516 [min] / 0.0250516 [max] (secs)
# Linear solver (S6NKT5BK__system-execute)
# Linear solver (S6NKT5BK__system-execute), solution time 2.163277e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# Step:    16 Model Time: 3936.5 year dt:  246.0 year (2025-05-21 13:57:00)
# Linear solver (WY9ZYSO6__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001635 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0009819 secs / 1 its
#   Pressure Solve:         = 0.005562 secs / 5 its
#   Final V Solve:          = 0.0006622 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.033868 seconds
#
# Linear solver (WY9ZYSO6__system-execute), solution time 3.406950e-02 (secs)
# Time Integration
# 	2nd order:                 ZVOVQBBF__integrand -    0.0233 [min] /    0.0233 [max] (secs)
# Time Integration - 0.0232891 [min] / 0.0232891 [max] (secs)
# Linear solver (S6NKT5BK__system-execute)
# Linear solver (S6NKT5BK__system-execute), solution time 1.386715e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# Step:    17 Model Time: 4182.6 year dt:  246.0 year (2025-05-21 13:57:01)
# Linear solver (WY9ZYSO6__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001497 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0007163 secs / 1 its
#   Pressure Solve:         = 0.004114 secs / 5 its
#   Final V Solve:          = 0.0008616 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.028956 seconds
#
# Linear solver (WY9ZYSO6__system-execute), solution time 2.915726e-02 (secs)
# Time Integration
# 	2nd order:                 ZVOVQBBF__integrand -    0.0258 [min] /    0.0258 [max] (secs)
# Time Integration - 0.0258114 [min] / 0.0258114 [max] (secs)
# Linear solver (S6NKT5BK__system-execute)
# Linear solver (S6NKT5BK__system-execute), solution time 1.488093e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# Step:    18 Model Time: 4428.6 year dt:  246.0 year (2025-05-21 13:57:01)
# Linear solver (WY9ZYSO6__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001433 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0009578 secs / 1 its
#   Pressure Solve:         = 0.004357 secs / 5 its
#   Final V Solve:          = 0.001007 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.032613 seconds
#
# Linear solver (WY9ZYSO6__system-execute), solution time 3.282904e-02 (secs)
# Time Integration
# 	2nd order:                 ZVOVQBBF__integrand -    0.0244 [min] /    0.0244 [max] (secs)
# Time Integration - 0.0244049 [min] / 0.0244049 [max] (secs)
# Linear solver (S6NKT5BK__system-execute)
# Linear solver (S6NKT5BK__system-execute), solution time 1.491380e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# Step:    19 Model Time: 4674.6 year dt:  246.0 year (2025-05-21 13:57:01)
# Linear solver (WY9ZYSO6__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.002180 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.001036 secs / 1 its
#   Pressure Solve:         = 0.006195 secs / 5 its
#   Final V Solve:          = 0.000881 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.039356 seconds
#
# Linear solver (WY9ZYSO6__system-execute), solution time 3.967860e-02 (secs)
# Time Integration
# 	2nd order:                 ZVOVQBBF__integrand -    0.0232 [min] /    0.0232 [max] (secs)
# Time Integration - 0.0232629 [min] / 0.0232629 [max] (secs)
# Linear solver (S6NKT5BK__system-execute)
# Linear solver (S6NKT5BK__system-execute), solution time 1.296536e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# Step:    20 Model Time: 4920.7 year dt:  246.0 year (2025-05-21 13:57:02)
# Linear solver (WY9ZYSO6__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001514 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0006651 secs / 1 its
#   Pressure Solve:         = 0.00368 secs / 5 its
#   Final V Solve:          = 0.0004991 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.029336 seconds
#
# Linear solver (WY9ZYSO6__system-execute), solution time 2.955002e-02 (secs)
# Time Integration
# 	2nd order:                 ZVOVQBBF__integrand -    0.0242 [min] /    0.0242 [max] (secs)
# Time Integration - 0.024281 [min] / 0.024281 [max] (secs)
# Linear solver (S6NKT5BK__system-execute)
# Linear solver (S6NKT5BK__system-execute), solution time 1.397456e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# Step:    21 Model Time: 4920.7 year dt:    0.0 second (2025-05-21 13:57:03)
# Linear solver (WY9ZYSO6__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001500 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.001252 secs / 1 its
#   Pressure Solve:         = 0.003966 secs / 5 its
#   Final V Solve:          = 0.0005464 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.032988 seconds
#
# Linear solver (WY9ZYSO6__system-execute), solution time 3.319953e-02 (secs)
# Time Integration
# 	2nd order:                 ZVOVQBBF__integrand -    0.0260 [min] /    0.0260 [max] (secs)
# Time Integration - 0.0260392 [min] / 0.0260392 [max] (secs)
# Linear solver (S6NKT5BK__system-execute)
# Linear solver (S6NKT5BK__system-execute), solution time 1.608865e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# Step:    22 Model Time: 5166.7 year dt:  246.0 year (2025-05-21 13:57:03)
# Linear solver (WY9ZYSO6__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001769 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0007421 secs / 1 its
#   Pressure Solve:         = 0.003992 secs / 5 its
#   Final V Solve:          = 0.0008987 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.031200 seconds
#
# Linear solver (WY9ZYSO6__system-execute), solution time 3.141219e-02 (secs)
# Time Integration
# 	2nd order:                 ZVOVQBBF__integrand -    0.0240 [min] /    0.0240 [max] (secs)
# Time Integration - 0.0240136 [min] / 0.0240136 [max] (secs)
# Linear solver (S6NKT5BK__system-execute)
# Linear solver (S6NKT5BK__system-execute), solution time 1.371883e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# Step:    23 Model Time: 5412.7 year dt:  246.0 year (2025-05-21 13:57:03)
# Linear solver (WY9ZYSO6__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001402 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.001335 secs / 1 its
#   Pressure Solve:         = 0.006317 secs / 5 its
#   Final V Solve:          = 0.0008564 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.032649 seconds
#
# Linear solver (WY9ZYSO6__system-execute), solution time 3.286634e-02 (secs)
# Time Integration
# 	2nd order:                 ZVOVQBBF__integrand -    0.0241 [min] /    0.0241 [max] (secs)
# Time Integration - 0.0241457 [min] / 0.0241457 [max] (secs)
# Linear solver (S6NKT5BK__system-execute)
# Linear solver (S6NKT5BK__system-execute), solution time 1.388802e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# Step:    24 Model Time: 5658.8 year dt:  246.0 year (2025-05-21 13:57:03)
# Linear solver (WY9ZYSO6__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001440 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.001081 secs / 1 its
#   Pressure Solve:         = 0.00679 secs / 5 its
#   Final V Solve:          = 0.0009997 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.035291 seconds
#
# Linear solver (WY9ZYSO6__system-execute), solution time 3.552253e-02 (secs)
# Time Integration
# 	2nd order:                 ZVOVQBBF__integrand -    0.0241 [min] /    0.0241 [max] (secs)
# Time Integration - 0.0241416 [min] / 0.0241416 [max] (secs)
# Linear solver (S6NKT5BK__system-execute)
# Linear solver (S6NKT5BK__system-execute), solution time 1.435849e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# Step:    25 Model Time: 5904.8 year dt:  246.0 year (2025-05-21 13:57:04)
# Linear solver (WY9ZYSO6__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001426 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0009067 secs / 1 its
#   Pressure Solve:         = 0.005694 secs / 5 its
#   Final V Solve:          = 0.001247 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.032318 seconds
#
# Linear solver (WY9ZYSO6__system-execute), solution time 3.255837e-02 (secs)
# Time Integration
# 	2nd order:                 ZVOVQBBF__integrand -    0.0242 [min] /    0.0242 [max] (secs)
# Time Integration - 0.0241954 [min] / 0.0241954 [max] (secs)
# Linear solver (S6NKT5BK__system-execute)
# Linear solver (S6NKT5BK__system-execute), solution time 1.486775e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# Step:    26 Model Time: 6150.8 year dt:  246.0 year (2025-05-21 13:57:04)
# Linear solver (WY9ZYSO6__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001443 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0006701 secs / 1 its
#   Pressure Solve:         = 0.005086 secs / 5 its
#   Final V Solve:          = 0.0009495 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.032177 seconds
#
# Linear solver (WY9ZYSO6__system-execute), solution time 3.239426e-02 (secs)
# Time Integration
# 	2nd order:                 ZVOVQBBF__integrand -    0.0243 [min] /    0.0243 [max] (secs)
# Time Integration - 0.0242825 [min] / 0.0242825 [max] (secs)
# Linear solver (S6NKT5BK__system-execute)
# Linear solver (S6NKT5BK__system-execute), solution time 1.417866e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# Step:    27 Model Time: 6150.8 year dt:    0.0 second (2025-05-21 13:57:05)
# Linear solver (WY9ZYSO6__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001455 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0005935 secs / 1 its
#   Pressure Solve:         = 0.004151 secs / 5 its
#   Final V Solve:          = 0.0009451 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.027860 seconds
#
# Linear solver (WY9ZYSO6__system-execute), solution time 2.810332e-02 (secs)
# Time Integration
# 	2nd order:                 ZVOVQBBF__integrand -    0.0262 [min] /    0.0262 [max] (secs)
# Time Integration - 0.026215 [min] / 0.026215 [max] (secs)
# Linear solver (S6NKT5BK__system-execute)
# Linear solver (S6NKT5BK__system-execute), solution time 1.458125e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# Step:    28 Model Time: 6396.9 year dt:  246.0 year (2025-05-21 13:57:05)
# Linear solver (WY9ZYSO6__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001424 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.001024 secs / 1 its
#   Pressure Solve:         = 0.00487 secs / 5 its
#   Final V Solve:          = 0.0008959 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.034542 seconds
#
# Linear solver (WY9ZYSO6__system-execute), solution time 3.475982e-02 (secs)
# Time Integration
# 	2nd order:                 ZVOVQBBF__integrand -    0.0245 [min] /    0.0245 [max] (secs)
# Time Integration - 0.0245745 [min] / 0.0245745 [max] (secs)
# Linear solver (S6NKT5BK__system-execute)
# Linear solver (S6NKT5BK__system-execute), solution time 1.438833e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# Step:    29 Model Time: 6642.9 year dt:  246.0 year (2025-05-21 13:57:06)
# Linear solver (WY9ZYSO6__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001636 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.001109 secs / 1 its
#   Pressure Solve:         = 0.006085 secs / 5 its
#   Final V Solve:          = 0.0009069 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.036462 seconds
#
# Linear solver (WY9ZYSO6__system-execute), solution time 3.670780e-02 (secs)
# Time Integration
# 	2nd order:                 ZVOVQBBF__integrand -    0.0262 [min] /    0.0262 [max] (secs)
# Time Integration - 0.0262716 [min] / 0.0262716 [max] (secs)
# Linear solver (S6NKT5BK__system-execute)
# Linear solver (S6NKT5BK__system-execute), solution time 1.685532e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# Step:    30 Model Time: 6888.9 year dt:  246.0 year (2025-05-21 13:57:06)
# Linear solver (WY9ZYSO6__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001422 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0009842 secs / 1 its
#   Pressure Solve:         = 0.003334 secs / 5 its
#   Final V Solve:          = 0.000581 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.030933 seconds
#
# Linear solver (WY9ZYSO6__system-execute), solution time 3.114520e-02 (secs)
# Time Integration
# 	2nd order:                 ZVOVQBBF__integrand -    0.0245 [min] /    0.0245 [max] (secs)
# Time Integration - 0.0245684 [min] / 0.0245684 [max] (secs)
# Linear solver (S6NKT5BK__system-execute)
# Linear solver (S6NKT5BK__system-execute), solution time 2.563385e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# Step:    31 Model Time: 7135.0 year dt:  246.0 year (2025-05-21 13:57:06)
# Linear solver (WY9ZYSO6__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001660 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0006254 secs / 1 its
#   Pressure Solve:         = 0.00582 secs / 5 its
#   Final V Solve:          = 0.0008734 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.032286 seconds
#
# Linear solver (WY9ZYSO6__system-execute), solution time 3.251876e-02 (secs)
# Time Integration
# 	2nd order:                 ZVOVQBBF__integrand -    0.0238 [min] /    0.0238 [max] (secs)
# Time Integration - 0.0238038 [min] / 0.0238038 [max] (secs)
# Linear solver (S6NKT5BK__system-execute)
# Linear solver (S6NKT5BK__system-execute), solution time 1.346242e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# Step:    32 Model Time: 7381.0 year dt:  246.0 year (2025-05-21 13:57:06)
# Linear solver (WY9ZYSO6__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001441 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0009979 secs / 1 its
#   Pressure Solve:         = 0.00513 secs / 5 its
#   Final V Solve:          = 0.0005798 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.032782 seconds
#
# Linear solver (WY9ZYSO6__system-execute), solution time 3.302132e-02 (secs)
# Time Integration
# 	2nd order:                 ZVOVQBBF__integrand -    0.0263 [min] /    0.0263 [max] (secs)
# Time Integration - 0.0262801 [min] / 0.0262801 [max] (secs)
# Linear solver (S6NKT5BK__system-execute)
# Linear solver (S6NKT5BK__system-execute), solution time 1.630542e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# Step:    33 Model Time: 7381.0 year dt:    0.0 second (2025-05-21 13:57:07)
# Linear solver (WY9ZYSO6__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001435 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0009853 secs / 1 its
#   Pressure Solve:         = 0.004808 secs / 5 its
#   Final V Solve:          = 0.00105 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.030655 seconds
#
# Linear solver (WY9ZYSO6__system-execute), solution time 3.092179e-02 (secs)
# Time Integration
# 	2nd order:                 ZVOVQBBF__integrand -    0.0267 [min] /    0.0267 [max] (secs)
# Time Integration - 0.0266845 [min] / 0.0266845 [max] (secs)
# Linear solver (S6NKT5BK__system-execute)
# Linear solver (S6NKT5BK__system-execute), solution time 1.650103e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# Step:    34 Model Time: 7627.0 year dt:  246.0 year (2025-05-21 13:57:08)
# Linear solver (WY9ZYSO6__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001543 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.00109 secs / 1 its
#   Pressure Solve:         = 0.005306 secs / 5 its
#   Final V Solve:          = 0.0008622 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.033234 seconds
#
# Linear solver (WY9ZYSO6__system-execute), solution time 3.347086e-02 (secs)
# Time Integration
# 	2nd order:                 ZVOVQBBF__integrand -    0.0248 [min] /    0.0248 [max] (secs)
# Time Integration - 0.0247974 [min] / 0.0247974 [max] (secs)
# Linear solver (S6NKT5BK__system-execute)
# Linear solver (S6NKT5BK__system-execute), solution time 1.463631e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# Step:    35 Model Time: 7873.1 year dt:  246.0 year (2025-05-21 13:57:08)
# Linear solver (WY9ZYSO6__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001503 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0007858 secs / 1 its
#   Pressure Solve:         = 0.004754 secs / 5 its
#   Final V Solve:          = 0.001007 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.031551 seconds
#
# Linear solver (WY9ZYSO6__system-execute), solution time 3.186463e-02 (secs)
# Time Integration
# 	2nd order:                 ZVOVQBBF__integrand -    0.0242 [min] /    0.0242 [max] (secs)
# Time Integration - 0.0242504 [min] / 0.0242504 [max] (secs)
# Linear solver (S6NKT5BK__system-execute)
# Linear solver (S6NKT5BK__system-execute), solution time 1.394241e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# Step:    36 Model Time: 8119.1 year dt:  246.0 year (2025-05-21 13:57:08)
# Linear solver (WY9ZYSO6__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001575 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0006213 secs / 1 its
#   Pressure Solve:         = 0.004889 secs / 5 its
#   Final V Solve:          = 0.0008751 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.030751 seconds
#
# Linear solver (WY9ZYSO6__system-execute), solution time 3.099583e-02 (secs)
# Time Integration
# 	2nd order:                 ZVOVQBBF__integrand -    0.0238 [min] /    0.0238 [max] (secs)
# Time Integration - 0.0238517 [min] / 0.0238517 [max] (secs)
# Linear solver (S6NKT5BK__system-execute)
# Linear solver (S6NKT5BK__system-execute), solution time 1.395270e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# Step:    37 Model Time: 8365.1 year dt:  246.0 year (2025-05-21 13:57:09)
# Linear solver (WY9ZYSO6__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001436 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0006079 secs / 1 its
#   Pressure Solve:         = 0.002978 secs / 5 its
#   Final V Solve:          = 0.0004853 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.027152 seconds
#
# Linear solver (WY9ZYSO6__system-execute), solution time 2.734654e-02 (secs)
# Time Integration
# 	2nd order:                 ZVOVQBBF__integrand -    0.0250 [min] /    0.0250 [max] (secs)
# Time Integration - 0.0249948 [min] / 0.0249948 [max] (secs)
# Linear solver (S6NKT5BK__system-execute)
# Linear solver (S6NKT5BK__system-execute), solution time 1.373989e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# Step:    38 Model Time: 8611.2 year dt:  246.0 year (2025-05-21 13:57:09)
# Linear solver (WY9ZYSO6__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001511 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.000689 secs / 1 its
#   Pressure Solve:         = 0.003074 secs / 5 its
#   Final V Solve:          = 0.0004962 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.030879 seconds
#
# Linear solver (WY9ZYSO6__system-execute), solution time 3.131793e-02 (secs)
# Time Integration
# 	2nd order:                 ZVOVQBBF__integrand -    0.0243 [min] /    0.0243 [max] (secs)
# Time Integration - 0.0243234 [min] / 0.0243234 [max] (secs)
# Linear solver (S6NKT5BK__system-execute)
# Linear solver (S6NKT5BK__system-execute), solution time 1.347342e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# Step:    39 Model Time: 8611.2 year dt:    0.0 second (2025-05-21 13:57:10)
# Linear solver (WY9ZYSO6__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001495 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.001231 secs / 1 its
#   Pressure Solve:         = 0.005739 secs / 5 its
#   Final V Solve:          = 0.00141 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.034315 seconds
#
# Linear solver (WY9ZYSO6__system-execute), solution time 3.474148e-02 (secs)
# Time Integration
# 	2nd order:                 ZVOVQBBF__integrand -    0.0275 [min] /    0.0275 [max] (secs)
# Time Integration - 0.0275409 [min] / 0.0275409 [max] (secs)
# Linear solver (S6NKT5BK__system-execute)
# Linear solver (S6NKT5BK__system-execute), solution time 1.501815e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# ...
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# Step:   394 Model Time: 95461.0 year dt:  246.0 year (2025-05-21 13:59:49)
# Linear solver (WY9ZYSO6__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001646 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.001082 secs / 1 its
#   Pressure Solve:         = 0.006357 secs / 5 its
#   Final V Solve:          = 0.001068 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.035114 seconds
#
# Linear solver (WY9ZYSO6__system-execute), solution time 3.540507e-02 (secs)
# Time Integration
# 	2nd order:                 ZVOVQBBF__integrand -    0.0260 [min] /    0.0260 [max] (secs)
# Time Integration - 0.0260536 [min] / 0.0260536 [max] (secs)
# Linear solver (S6NKT5BK__system-execute)
# Linear solver (S6NKT5BK__system-execute), solution time 1.522118e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# Step:   395 Model Time: 95707.0 year dt:  246.0 year (2025-05-21 13:59:49)
# Linear solver (WY9ZYSO6__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001588 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.001182 secs / 1 its
#   Pressure Solve:         = 0.004878 secs / 5 its
#   Final V Solve:          = 0.0005989 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.032005 seconds
#
# Linear solver (WY9ZYSO6__system-execute), solution time 3.226450e-02 (secs)
# Time Integration
# 	2nd order:                 ZVOVQBBF__integrand -    0.0279 [min] /    0.0279 [max] (secs)
# Time Integration - 0.0279154 [min] / 0.0279154 [max] (secs)
# Linear solver (S6NKT5BK__system-execute)
# Linear solver (S6NKT5BK__system-execute), solution time 1.948471e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# Step:   396 Model Time: 95953.0 year dt:  246.0 year (2025-05-21 13:59:50)
# Linear solver (WY9ZYSO6__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001683 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0006178 secs / 1 its
#   Pressure Solve:         = 0.004922 secs / 5 its
#   Final V Solve:          = 0.000546 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.030988 seconds
#
# Linear solver (WY9ZYSO6__system-execute), solution time 3.125587e-02 (secs)
# Time Integration
# 	2nd order:                 ZVOVQBBF__integrand -    0.0276 [min] /    0.0276 [max] (secs)
# Time Integration - 0.0276146 [min] / 0.0276146 [max] (secs)
# Linear solver (S6NKT5BK__system-execute)
# Linear solver (S6NKT5BK__system-execute), solution time 1.647901e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# Step:   397 Model Time: 96199.1 year dt:  246.0 year (2025-05-21 13:59:51)
# Linear solver (WY9ZYSO6__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001617 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.001251 secs / 1 its
#   Pressure Solve:         = 0.004558 secs / 5 its
#   Final V Solve:          = 0.0009765 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.033477 seconds
#
# Linear solver (WY9ZYSO6__system-execute), solution time 3.373441e-02 (secs)
# Time Integration
# 	2nd order:                 ZVOVQBBF__integrand -    0.0276 [min] /    0.0276 [max] (secs)
# Time Integration - 0.0276391 [min] / 0.0276391 [max] (secs)
# Linear solver (S6NKT5BK__system-execute)
# Linear solver (S6NKT5BK__system-execute), solution time 1.594138e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# Step:   398 Model Time: 96445.1 year dt:  246.0 year (2025-05-21 13:59:51)
# Linear solver (WY9ZYSO6__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.002013 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.001024 secs / 1 its
#   Pressure Solve:         = 0.00411 secs / 5 its
#   Final V Solve:          = 0.0005165 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.033463 seconds
#
# Linear solver (WY9ZYSO6__system-execute), solution time 3.389646e-02 (secs)
# Time Integration
# 	2nd order:                 ZVOVQBBF__integrand -    0.0277 [min] /    0.0277 [max] (secs)
# Time Integration - 0.0277215 [min] / 0.0277215 [max] (secs)
# Linear solver (S6NKT5BK__system-execute)
# Linear solver (S6NKT5BK__system-execute), solution time 1.533992e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# Step:   399 Model Time: 96691.1 year dt:  246.0 year (2025-05-21 13:59:51)
# Linear solver (WY9ZYSO6__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001661 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0006512 secs / 1 its
#   Pressure Solve:         = 0.002953 secs / 5 its
#   Final V Solve:          = 0.0004804 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.028586 seconds
#
# Linear solver (WY9ZYSO6__system-execute), solution time 2.883546e-02 (secs)
# Time Integration
# 	2nd order:                 ZVOVQBBF__integrand -    0.0261 [min] /    0.0261 [max] (secs)
# Time Integration - 0.0261698 [min] / 0.0261698 [max] (secs)
# Linear solver (S6NKT5BK__system-execute)
# Linear solver (S6NKT5BK__system-execute), solution time 1.467312e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# Step:   400 Model Time: 96937.2 year dt:  246.0 year (2025-05-21 13:59:52)
# Linear solver (WY9ZYSO6__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001638 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0005915 secs / 1 its
#   Pressure Solve:         = 0.003074 secs / 5 its
#   Final V Solve:          = 0.0005661 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.026870 seconds
#
# Linear solver (WY9ZYSO6__system-execute), solution time 2.713875e-02 (secs)
# Time Integration
# 	2nd order:                 ZVOVQBBF__integrand -    0.0261 [min] /    0.0261 [max] (secs)
# Time Integration - 0.0261665 [min] / 0.0261665 [max] (secs)
# Linear solver (S6NKT5BK__system-execute)
# Linear solver (S6NKT5BK__system-execute), solution time 1.454065e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# Step:   401 Model Time: 97183.2 year dt:  246.0 year (2025-05-21 13:59:53)
# Linear solver (WY9ZYSO6__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001780 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.001154 secs / 1 its
#   Pressure Solve:         = 0.004976 secs / 5 its
#   Final V Solve:          = 0.0005212 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.032258 seconds
#
# Linear solver (WY9ZYSO6__system-execute), solution time 3.253468e-02 (secs)
# Time Integration
# 	2nd order:                 ZVOVQBBF__integrand -    0.0286 [min] /    0.0286 [max] (secs)
# Time Integration - 0.0286424 [min] / 0.0286424 [max] (secs)
# Linear solver (S6NKT5BK__system-execute)
# Linear solver (S6NKT5BK__system-execute), solution time 1.525584e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# Step:   402 Model Time: 97429.2 year dt:  246.0 year (2025-05-21 13:59:53)
# Linear solver (WY9ZYSO6__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001645 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.001056 secs / 1 its
#   Pressure Solve:         = 0.003591 secs / 5 its
#   Final V Solve:          = 0.0005001 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.031568 seconds
#
# Linear solver (WY9ZYSO6__system-execute), solution time 3.181708e-02 (secs)
# Time Integration
# 	2nd order:                 ZVOVQBBF__integrand -    0.0283 [min] /    0.0283 [max] (secs)
# Time Integration - 0.0283355 [min] / 0.0283355 [max] (secs)
# Linear solver (S6NKT5BK__system-execute)
# Linear solver (S6NKT5BK__system-execute), solution time 1.535970e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# Step:   403 Model Time: 97675.3 year dt:  246.0 year (2025-05-21 13:59:53)
# Linear solver (WY9ZYSO6__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001619 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.001101 secs / 1 its
#   Pressure Solve:         = 0.003329 secs / 5 its
#   Final V Solve:          = 0.0004978 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.030897 seconds
#
# Linear solver (WY9ZYSO6__system-execute), solution time 3.115637e-02 (secs)
# Time Integration
# 	2nd order:                 ZVOVQBBF__integrand -    0.0291 [min] /    0.0291 [max] (secs)
# Time Integration - 0.0291249 [min] / 0.0291249 [max] (secs)
# Linear solver (S6NKT5BK__system-execute)
# Linear solver (S6NKT5BK__system-execute), solution time 1.605346e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# Step:   404 Model Time: 97921.3 year dt:  246.0 year (2025-05-21 13:59:54)
# Linear solver (WY9ZYSO6__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001684 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.001023 secs / 1 its
#   Pressure Solve:         = 0.005348 secs / 5 its
#   Final V Solve:          = 0.00121 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.034686 seconds
#
# Linear solver (WY9ZYSO6__system-execute), solution time 3.498668e-02 (secs)
# Time Integration
# 	2nd order:                 ZVOVQBBF__integrand -    0.0279 [min] /    0.0279 [max] (secs)
# Time Integration - 0.0279639 [min] / 0.0279639 [max] (secs)
# Linear solver (S6NKT5BK__system-execute)
# Linear solver (S6NKT5BK__system-execute), solution time 1.483822e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# Step:   405 Model Time: 98167.3 year dt:  246.0 year (2025-05-21 13:59:54)
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# Linear solver (WY9ZYSO6__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001753 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0009949 secs / 1 its
#   Pressure Solve:         = 0.003386 secs / 5 its
#   Final V Solve:          = 0.0007451 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.032081 seconds
#
# Linear solver (WY9ZYSO6__system-execute), solution time 3.235199e-02 (secs)
# Time Integration
# 	2nd order:                 ZVOVQBBF__integrand -    0.0264 [min] /    0.0264 [max] (secs)
# Time Integration - 0.0263839 [min] / 0.0263839 [max] (secs)
# Linear solver (S6NKT5BK__system-execute)
# Linear solver (S6NKT5BK__system-execute), solution time 1.446795e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# Step:   406 Model Time: 98413.4 year dt:  246.0 year (2025-05-21 13:59:55)
# Linear solver (WY9ZYSO6__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001491 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.001255 secs / 1 its
#   Pressure Solve:         = 0.005858 secs / 5 its
#   Final V Solve:          = 0.0009293 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.031884 seconds
#
# Linear solver (WY9ZYSO6__system-execute), solution time 3.214214e-02 (secs)
# Time Integration
# 	2nd order:                 ZVOVQBBF__integrand -    0.0260 [min] /    0.0260 [max] (secs)
# Time Integration - 0.0259903 [min] / 0.0259903 [max] (secs)
# Linear solver (S6NKT5BK__system-execute)
# Linear solver (S6NKT5BK__system-execute), solution time 1.460118e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "8DKR51CR__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "8DKR51CR__swarm"
# Step:   407 Model Time: 98413.4 year dt:    0.0 second (2025-05-21 13:59:55)
# 1
