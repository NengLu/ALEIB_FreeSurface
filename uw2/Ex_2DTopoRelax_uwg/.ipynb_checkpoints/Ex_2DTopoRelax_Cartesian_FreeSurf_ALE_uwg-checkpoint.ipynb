# %%
import underworld as uw
import math
from underworld import function as fn
import numpy as np
import os

from underworld import UWGeodynamics as GEO
u = GEO.UnitRegistry
ndim = GEO.non_dimensionalise
dimen = GEO.dimensionalise

comm = uw.mpi.comm
rank = uw.mpi.rank
size = uw.mpi.size

#from _freesurface_ALEIB import FreeSurfaceProcessor_ALEIB
# Out:
# loaded rc file /home/nl/anaconda3/envs/uw2/lib/python3.11/site-packages/underworld/UWGeodynamics/uwgeo-data/uwgeodynamicsrc

# %%
# solver parameters
GEO.rcParams["initial.nonlinear.tolerance"] = 1e-3
GEO.rcParams['initial.nonlinear.max.iterations'] = 100
GEO.rcParams["nonlinear.tolerance"] = 1e-3
GEO.rcParams['nonlinear.max.iterations'] = 100
GEO.rcParams["popcontrol.particles.per.cell.2D"] = 16
GEO.rcParams["swarm.particles.per.cell.2D"] = 16
GEO.rcParams["surface.pressure.normalization"] = True
GEO.rcParams["pressure.smoothing"] = True
GEO.rcParams["popcontrol.split.threshold"] = 0.1

# %%
# scaling 3: vel
half_rate = 1.0 * u.centimeter / u.year
model_length = 500. * u.kilometer
gravity = 9.81 * u.meter / u.second**2
bodyforce = 3300 * u.kilogram / u.metre**3 *gravity 

KL = model_length
Kt = KL / half_rate
KM = bodyforce * KL**2 * Kt**2

GEO.scaling_coefficients["[length]"] = KL
GEO.scaling_coefficients["[time]"] = Kt
GEO.scaling_coefficients["[mass]"]= KM

# %%
xmin, xmax = ndim(-250 * u.kilometer), ndim(250 * u.kilometer)
ymin, ymax = ndim(-500 * u.kilometer), ndim(0 * u.kilometer)
yint = 0.
 
dy = ndim(500 * u.kilometer)/50
dx = dy
xRes,yRes = int((xmax-xmin)/dx),int((ymax-ymin)/dy)
yResa,yResb =int((ymax-yint)/dy),int((yint-ymin)/dy)

#tRatio =  int(sys.argv[1])
tRatio = 100
save_every = 1
use_fssa = False
if use_fssa:
    outputPath = "op_Ex_2DTopoRelax_FreeSurf_ALE_withFSSA0.5_yres{:n}_tRatio{:n}_Swarm_uwg".format(yRes,tRatio)
    save_every = 1
else:
    outputPath = "op_Ex_2DTopoRelax_FreeSurf_ALE_noFSSA_yres{:n}_tRatio{:n}_Swarm_uwg".format(yRes,tRatio)
    save_every = 5

# %%
Model = GEO.Model(elementRes=(xRes, yRes),
                  minCoord=(xmin,ymin),
                  maxCoord=(xmax, ymax),
                  gravity=(0.0, -gravity),
                  periodic=(True, False))
Model.outputDir= outputPath
Model.minStrainRate = 1e-18 / u.second
# Out:
# 	Global element size: 50x50
# 	Local offset of rank 0: 0x0
# 	Local range of rank 0: 50x50
# In func WeightsCalculator_CalculateAll(): for swarm "0UGIYMZ7__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "0UGIYMZ7__swarm"

# %%
wRatio = 1
D = np.abs(ymin)
Lambda = D/wRatio
k = 2.0 * np.pi / Lambda
mu0 = ndim(1e21  * u.pascal * u.second)
g = ndim(gravity)
rho0 = ndim(3300* u.kilogram / u.metre**3)
drho = rho0-0.
w_m = ndim(10*u.kilometer)

tau0 = 2*k*mu0/drho/g
tau = (D*k+np.sinh(D*k)*np.cosh(D*k))/(np.sinh(D*k)**2)*tau0

def perturbation(x):
    return w_m * np.cos(2.*np.pi*(x)/Lambda)

fn_coord = fn.input()
deform_fn = w_m * fn.math.cos(2.*np.pi*fn_coord[0]/Lambda)

# def get_analytical(x0,load_time):
#     #tau = (D*k+np.sinh(D*k)*np.cosh(D*k))/(np.sinh(D*k)**2)*tau0
#     #A = -F0/k/tau0
#     #B = -F0/k/tau
#     #C = F0/tau
#     #E = F0/tau/np.tanh(D*k)
#     #phi = np.sin(k*x)*np.exp(-tmax/tau)*(A*np.sinh(k*z)+B*np.cosh(k*z)+C*z*np.sinh(k*z)+E*z*np.cosh(k*z))
#     w = w_m*np.exp(-load_time/tau)
#     return w

max_time =  tau*4
dt_set = tau/tRatio

# %%
# D_ib = yint
# axis_ib = np.where((Model.mesh.data[:,1]<=D_ib+dy/4)&(Model.mesh.data[:,1]>=D_ib-dy/4))
# Sets_ib = Model.mesh.specialSets["Empty"]
# for index in axis_ib:
#     Sets_ib.add(index)

minCoord = tuple([GEO.nd(val) for val in Model.minCoord])
maxCoord = tuple([GEO.nd(val) for val in Model.maxCoord])

init_mesh = uw.mesh.FeMesh_Cartesian(elementType=Model.elementType,
                                    elementRes=Model.elementRes,
                                    minCoord=minCoord,
                                    maxCoord=maxCoord,
                                    periodic=Model.periodic)

TField = init_mesh.add_variable(nodeDofCount=1)
TField.data[:, 0] = init_mesh.data[:, 1].copy()

top = Model.top_wall
bottom = Model.bottom_wall
conditions = uw.conditions.DirichletCondition(variable=TField,indexSetsPerDof=(top + bottom,))
system = uw.systems.SteadyStateHeat(
    temperatureField=TField,
    fn_diffusivity=1.0,
    conditions=conditions)
solver = uw.systems.Solver(system)

TField.data[top, 0] = perturbation(init_mesh.data[top,0])  

solver.solve()
with Model.mesh.deform_mesh():
     Model.mesh.data[:, -1] = TField.data[:, 0].copy()
# Out:
# 	Global element size: 50x50
# 	Local offset of rank 0: 0x0
# 	Local range of rank 0: 50x50
# Linear solver (Y23ROMXH__system-execute)
# Linear solver (Y23ROMXH__system-execute), solution time 2.024108e-03 (secs)

# %%
# if size == 1:
#     from underworld import visualisation as vis
#     Fig = vis.Figure(resolution=(500,500),rulers=True,margin = 20)
#     Fig.Mesh(Model.mesh)
#     Fig.show()
#     Fig.save('mesh0.png')
# Out:
# <img src='data:image/png;base64,...'>

# %%
from underworld.swarm import Swarm
from collections import OrderedDict
Model.swarm_variables = OrderedDict()
Model.swarm = Swarm(mesh=Model.mesh, particleEscape=True)
Model.swarm.allow_parallel_nn = True
if Model.mesh.dim == 2:
    particlesPerCell = GEO.rcParams["swarm.particles.per.cell.2D"]
else:
    particlesPerCell = GEO.rcParams["swarm.particles.per.cell.3D"]
Model._swarmLayout = uw.swarm.layouts.PerCellSpaceFillerLayout(
    swarm=Model.swarm,
    particlesPerCell=particlesPerCell)

Model.swarm.populate_using_layout(layout=Model._swarmLayout)
Model._initialize()
# Out:
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"

# %%
materialAShape = fn_coord[1] > deform_fn #GEO.shapes.Layer(top=Model.top, bottom=Model.bottom)
materialMShape = fn_coord[1] <= xmax+w_m*5

#materialA = Model.add_material(name="Air", shape=materialAShape)
materialM = Model.add_material(name="Mantle", shape=materialMShape)

# %%
# if uw.mpi.rank == 0:
#     from underworld import visualisation as vis
#     fig_res = (500,500)

#     Fig = vis.Figure(resolution=fig_res,rulers=False,margin = 20,rulerticks=7,quality=2,clipmap=False) 
#     Fig.Points(Model.swarm, Model.materialField,fn_size=2.0,discrete=True,colourBar=True,colours='blue orange')
#     Fig.Mesh(Model.mesh)
#     Fig.show()
#     Fig.save("Modelsetup.png")
# Out:
# <img src='data:image/png;base64,...'>

# %%
# Model.maxViscosity = 1e21 * u.pascal * u.second
# Model.minViscosity = 1e18 * u.pascal * u.second

#materialA.viscosity = 1e18 * u.pascal * u.second
materialM.viscosity = 1e21 * u.pascal * u.second

#materialA.density = 0.
materialM.density = 3300 * u.kilogram / u.metre**3

# %%
Model.set_velocityBCs(left=[0.,None],right=[0,None],bottom=[0.,0.], top=[None,None])

Model.init_model()

Model.solver.set_inner_method("mumps")
Model.solver.set_penalty(1e3)
# Out:
# /home/nl/anaconda3/envs/uw2/lib/python3.11/site-packages/underworld/UWGeodynamics/_model.py:1595: UserWarning: Skipping the steady state calculation: No diffusivity variable defined on Model
#   warnings.warn("Skipping the steady state calculation: No diffusivity variable defined on Model")

# %%
Model.freeSurface = True
# Model.inter_wall = Sets_ib
# Model._freeSurface = FreeSurfaceProcessor_ALEIB(Model)
# Out:
# 	Global element size: 50x50
# 	Local offset of rank 0: 0x0
# 	Local range of rank 0: 50x50

# %%
if use_fssa:
    Model._fssa_factor = 0.5

# %%
max_time = dimen(tau*4,u.kiloyear)
dt_set = dimen(tau/tRatio,u.kiloyear)
checkpoint_interval = dt_set*save_every 

Model.run_for(max_time, checkpoint_interval=checkpoint_interval,dt=dt_set)
# Out:
# Options:  -Q22_pc_type gkgdiag -force_correction True -ksp_type bsscr -pc_type none -ksp_k2_type NULL -rescale_equations False -remove_constant_pressure_null_space False -change_backsolve False -change_A11rhspresolve False -restore_K False -A11_ksp_type preonly -A11_pc_type lu -A11_pc_factor_mat_solver_type mumps -scr_ksp_type fgmres -scr_ksp_rtol 1e-05 -A11_mg_active False
# Linear solver (AWWHLA1I__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001672 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.000729 secs / 1 its
#   Pressure Solve:         = 0.002875 secs / 5 its
#   Final V Solve:          = 0.0007993 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.023360 seconds
#
# Linear solver (AWWHLA1I__system-execute), solution time 2.361382e-02 (secs)
# Time Integration
# 	2nd order:                 Y4NXFZ96__integrand -    0.0208 [min] /    0.0208 [max] (secs)
# Time Integration - 0.0207943 [min] / 0.0207943 [max] (secs)
# Linear solver (MN5UEGUL__system-execute)
# Linear solver (MN5UEGUL__system-execute), solution time 1.288351e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# Step:     1 Model Time:  246.0 year dt:  246.0 year (2025-05-21 14:13:32)
# Linear solver (AWWHLA1I__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001528 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0008078 secs / 1 its
#   Pressure Solve:         = 0.00344 secs / 5 its
#   Final V Solve:          = 0.0004107 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.022568 seconds
#
# Linear solver (AWWHLA1I__system-execute), solution time 2.276882e-02 (secs)
# Time Integration
# 	2nd order:                 Y4NXFZ96__integrand -    0.0222 [min] /    0.0222 [max] (secs)
# Time Integration - 0.0222024 [min] / 0.0222024 [max] (secs)
# Linear solver (MN5UEGUL__system-execute)
# Linear solver (MN5UEGUL__system-execute), solution time 1.360776e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# Step:     2 Model Time:  492.1 year dt:  246.0 year (2025-05-21 14:13:33)
# Linear solver (AWWHLA1I__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001211 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0005572 secs / 1 its
#   Pressure Solve:         = 0.003556 secs / 5 its
#   Final V Solve:          = 0.000565 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.019363 seconds
#
# Linear solver (AWWHLA1I__system-execute), solution time 1.954397e-02 (secs)
# Time Integration
# 	2nd order:                 Y4NXFZ96__integrand -    0.0206 [min] /    0.0206 [max] (secs)
# Time Integration - 0.0206667 [min] / 0.0206667 [max] (secs)
# Linear solver (MN5UEGUL__system-execute)
# Linear solver (MN5UEGUL__system-execute), solution time 1.282176e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# Step:     3 Model Time:  738.1 year dt:  246.0 year (2025-05-21 14:13:33)
# Linear solver (AWWHLA1I__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001386 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0005096 secs / 1 its
#   Pressure Solve:         = 0.003278 secs / 5 its
#   Final V Solve:          = 0.0009399 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.018195 seconds
#
# Linear solver (AWWHLA1I__system-execute), solution time 1.842541e-02 (secs)
# Time Integration
# 	2nd order:                 Y4NXFZ96__integrand -    0.0219 [min] /    0.0219 [max] (secs)
# Time Integration - 0.0219167 [min] / 0.0219167 [max] (secs)
# Linear solver (MN5UEGUL__system-execute)
# Linear solver (MN5UEGUL__system-execute), solution time 1.319987e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# Step:     4 Model Time:  984.1 year dt:  246.0 year (2025-05-21 14:13:33)
# Linear solver (AWWHLA1I__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001372 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0005245 secs / 1 its
#   Pressure Solve:         = 0.0025 secs / 5 its
#   Final V Solve:          = 0.0004116 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.017739 seconds
#
# Linear solver (AWWHLA1I__system-execute), solution time 1.793123e-02 (secs)
# Time Integration
# 	2nd order:                 Y4NXFZ96__integrand -    0.0223 [min] /    0.0223 [max] (secs)
# Time Integration - 0.0223604 [min] / 0.0223604 [max] (secs)
# Linear solver (MN5UEGUL__system-execute)
# Linear solver (MN5UEGUL__system-execute), solution time 1.351757e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# Step:     5 Model Time: 1230.2 year dt:  246.0 year (2025-05-21 14:13:34)
# Linear solver (AWWHLA1I__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001358 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0009884 secs / 1 its
#   Pressure Solve:         = 0.004321 secs / 5 its
#   Final V Solve:          = 0.0007011 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.021443 seconds
#
# Linear solver (AWWHLA1I__system-execute), solution time 2.164414e-02 (secs)
# Time Integration
# 	2nd order:                 Y4NXFZ96__integrand -    0.0236 [min] /    0.0236 [max] (secs)
# Time Integration - 0.0236673 [min] / 0.0236673 [max] (secs)
# Linear solver (MN5UEGUL__system-execute)
# Linear solver (MN5UEGUL__system-execute), solution time 1.286907e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# Step:     6 Model Time: 1476.2 year dt:  246.0 year (2025-05-21 14:13:34)
# Linear solver (AWWHLA1I__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.002135 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0008381 secs / 1 its
#   Pressure Solve:         = 0.00336 secs / 5 its
#   Final V Solve:          = 0.0004136 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.022080 seconds
#
# Linear solver (AWWHLA1I__system-execute), solution time 2.228645e-02 (secs)
# Time Integration
# 	2nd order:                 Y4NXFZ96__integrand -    0.0211 [min] /    0.0211 [max] (secs)
# Time Integration - 0.0210851 [min] / 0.0210851 [max] (secs)
# Linear solver (MN5UEGUL__system-execute)
# Linear solver (MN5UEGUL__system-execute), solution time 1.229162e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# Step:     7 Model Time: 1722.2 year dt:  246.0 year (2025-05-21 14:13:35)
# Linear solver (AWWHLA1I__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001460 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.001014 secs / 1 its
#   Pressure Solve:         = 0.003271 secs / 5 its
#   Final V Solve:          = 0.0007051 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.020417 seconds
#
# Linear solver (AWWHLA1I__system-execute), solution time 2.064342e-02 (secs)
# Time Integration
# 	2nd order:                 Y4NXFZ96__integrand -    0.0206 [min] /    0.0206 [max] (secs)
# Time Integration - 0.0206312 [min] / 0.0206312 [max] (secs)
# Linear solver (MN5UEGUL__system-execute)
# Linear solver (MN5UEGUL__system-execute), solution time 1.236372e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# Step:     8 Model Time: 1968.3 year dt:  246.0 year (2025-05-21 14:13:35)
# Linear solver (AWWHLA1I__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001286 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.000524 secs / 1 its
#   Pressure Solve:         = 0.002505 secs / 5 its
#   Final V Solve:          = 0.0004175 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.017397 seconds
#
# Linear solver (AWWHLA1I__system-execute), solution time 1.760778e-02 (secs)
# Time Integration
# 	2nd order:                 Y4NXFZ96__integrand -    0.0216 [min] /    0.0216 [max] (secs)
# Time Integration - 0.0216054 [min] / 0.0216054 [max] (secs)
# Linear solver (MN5UEGUL__system-execute)
# Linear solver (MN5UEGUL__system-execute), solution time 1.322070e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# Step:     9 Model Time: 2214.3 year dt:  246.0 year (2025-05-21 14:13:35)
# Linear solver (AWWHLA1I__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001396 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0008275 secs / 1 its
#   Pressure Solve:         = 0.003414 secs / 5 its
#   Final V Solve:          = 0.0004214 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.019894 seconds
#
# Linear solver (AWWHLA1I__system-execute), solution time 2.008039e-02 (secs)
# Time Integration
# 	2nd order:                 Y4NXFZ96__integrand -    0.0216 [min] /    0.0216 [max] (secs)
# Time Integration - 0.0216391 [min] / 0.0216391 [max] (secs)
# Linear solver (MN5UEGUL__system-execute)
# Linear solver (MN5UEGUL__system-execute), solution time 1.379560e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# Step:    10 Model Time: 2460.3 year dt:  246.0 year (2025-05-21 14:13:36)
# Linear solver (AWWHLA1I__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001345 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0008632 secs / 1 its
#   Pressure Solve:         = 0.003028 secs / 5 its
#   Final V Solve:          = 0.0004442 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.018613 seconds
#
# Linear solver (AWWHLA1I__system-execute), solution time 1.879139e-02 (secs)
# Time Integration
# 	2nd order:                 Y4NXFZ96__integrand -    0.0214 [min] /    0.0214 [max] (secs)
# Time Integration - 0.0214221 [min] / 0.0214221 [max] (secs)
# Linear solver (MN5UEGUL__system-execute)
# Linear solver (MN5UEGUL__system-execute), solution time 1.346295e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# Step:    11 Model Time: 2706.4 year dt:  246.0 year (2025-05-21 14:13:36)
# Linear solver (AWWHLA1I__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001313 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0008632 secs / 1 its
#   Pressure Solve:         = 0.003314 secs / 5 its
#   Final V Solve:          = 0.0004088 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.020062 seconds
#
# Linear solver (AWWHLA1I__system-execute), solution time 2.024809e-02 (secs)
# Time Integration
# 	2nd order:                 Y4NXFZ96__integrand -    0.0226 [min] /    0.0226 [max] (secs)
# Time Integration - 0.0225878 [min] / 0.0225878 [max] (secs)
# Linear solver (MN5UEGUL__system-execute)
# Linear solver (MN5UEGUL__system-execute), solution time 1.348615e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# Step:    12 Model Time: 2952.4 year dt:  246.0 year (2025-05-21 14:13:36)
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# Linear solver (AWWHLA1I__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001443 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0004976 secs / 1 its
#   Pressure Solve:         = 0.002483 secs / 5 its
#   Final V Solve:          = 0.0004896 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.018401 seconds
#
# Linear solver (AWWHLA1I__system-execute), solution time 1.860969e-02 (secs)
# Time Integration
# 	2nd order:                 Y4NXFZ96__integrand -    0.0226 [min] /    0.0226 [max] (secs)
# Time Integration - 0.0226542 [min] / 0.0226542 [max] (secs)
# Linear solver (MN5UEGUL__system-execute)
# Linear solver (MN5UEGUL__system-execute), solution time 1.316186e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# Step:    13 Model Time: 3198.4 year dt:  246.0 year (2025-05-21 14:13:37)
# Linear solver (AWWHLA1I__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001360 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0005754 secs / 1 its
#   Pressure Solve:         = 0.002608 secs / 5 its
#   Final V Solve:          = 0.0004289 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.018512 seconds
#
# Linear solver (AWWHLA1I__system-execute), solution time 1.870618e-02 (secs)
# Time Integration
# 	2nd order:                 Y4NXFZ96__integrand -    0.0237 [min] /    0.0237 [max] (secs)
# Time Integration - 0.0237364 [min] / 0.0237364 [max] (secs)
# Linear solver (MN5UEGUL__system-execute)
# Linear solver (MN5UEGUL__system-execute), solution time 1.297100e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# Step:    14 Model Time: 3444.5 year dt:  246.0 year (2025-05-21 14:13:37)
# Linear solver (AWWHLA1I__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001454 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0005167 secs / 1 its
#   Pressure Solve:         = 0.002462 secs / 5 its
#   Final V Solve:          = 0.0007108 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.016408 seconds
#
# Linear solver (AWWHLA1I__system-execute), solution time 1.660602e-02 (secs)
# Time Integration
# 	2nd order:                 Y4NXFZ96__integrand -    0.0230 [min] /    0.0230 [max] (secs)
# Time Integration - 0.0230574 [min] / 0.0230574 [max] (secs)
# Linear solver (MN5UEGUL__system-execute)
# Linear solver (MN5UEGUL__system-execute), solution time 1.408475e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# Step:    15 Model Time: 3690.5 year dt:  246.0 year (2025-05-21 14:13:38)
# Linear solver (AWWHLA1I__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001420 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0008416 secs / 1 its
#   Pressure Solve:         = 0.004289 secs / 5 its
#   Final V Solve:          = 0.0006031 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.022131 seconds
#
# Linear solver (AWWHLA1I__system-execute), solution time 2.233685e-02 (secs)
# Time Integration
# 	2nd order:                 Y4NXFZ96__integrand -    0.0213 [min] /    0.0213 [max] (secs)
# Time Integration - 0.0213303 [min] / 0.0213303 [max] (secs)
# Linear solver (MN5UEGUL__system-execute)
# Linear solver (MN5UEGUL__system-execute), solution time 1.263035e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# Step:    16 Model Time: 3936.5 year dt:  246.0 year (2025-05-21 14:13:38)
# Linear solver (AWWHLA1I__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001308 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0008575 secs / 1 its
#   Pressure Solve:         = 0.002912 secs / 5 its
#   Final V Solve:          = 0.0004109 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.019790 seconds
#
# Linear solver (AWWHLA1I__system-execute), solution time 1.998871e-02 (secs)
# Time Integration
# 	2nd order:                 Y4NXFZ96__integrand -    0.0210 [min] /    0.0210 [max] (secs)
# Time Integration - 0.0209801 [min] / 0.0209801 [max] (secs)
# Linear solver (MN5UEGUL__system-execute)
# Linear solver (MN5UEGUL__system-execute), solution time 1.299311e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# Step:    17 Model Time: 4182.6 year dt:  246.0 year (2025-05-21 14:13:38)
# Linear solver (AWWHLA1I__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001405 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0007926 secs / 1 its
#   Pressure Solve:         = 0.005061 secs / 5 its
#   Final V Solve:          = 0.000452 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.020129 seconds
#
# Linear solver (AWWHLA1I__system-execute), solution time 2.032922e-02 (secs)
# Time Integration
# 	2nd order:                 Y4NXFZ96__integrand -    0.0225 [min] /    0.0225 [max] (secs)
# Time Integration - 0.0225121 [min] / 0.0225121 [max] (secs)
# Linear solver (MN5UEGUL__system-execute)
# Linear solver (MN5UEGUL__system-execute), solution time 1.278166e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# Step:    18 Model Time: 4428.6 year dt:  246.0 year (2025-05-21 14:13:39)
# Linear solver (AWWHLA1I__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001330 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0009292 secs / 1 its
#   Pressure Solve:         = 0.00293 secs / 5 its
#   Final V Solve:          = 0.0004203 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.018563 seconds
#
# Linear solver (AWWHLA1I__system-execute), solution time 1.875411e-02 (secs)
# Time Integration
# 	2nd order:                 Y4NXFZ96__integrand -    0.0219 [min] /    0.0219 [max] (secs)
# Time Integration - 0.0219477 [min] / 0.0219477 [max] (secs)
# Linear solver (MN5UEGUL__system-execute)
# Linear solver (MN5UEGUL__system-execute), solution time 1.286991e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# Step:    19 Model Time: 4674.6 year dt:  246.0 year (2025-05-21 14:13:39)
# Linear solver (AWWHLA1I__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001379 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0004969 secs / 1 its
#   Pressure Solve:         = 0.003665 secs / 5 its
#   Final V Solve:          = 0.0005523 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.018061 seconds
#
# Linear solver (AWWHLA1I__system-execute), solution time 1.825921e-02 (secs)
# Time Integration
# 	2nd order:                 Y4NXFZ96__integrand -    0.0233 [min] /    0.0233 [max] (secs)
# Time Integration - 0.0232816 [min] / 0.0232816 [max] (secs)
# Linear solver (MN5UEGUL__system-execute)
# Linear solver (MN5UEGUL__system-execute), solution time 1.503074e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# Step:    20 Model Time: 4920.7 year dt:  246.0 year (2025-05-21 14:13:39)
# Linear solver (AWWHLA1I__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001405 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0008442 secs / 1 its
#   Pressure Solve:         = 0.00415 secs / 5 its
#   Final V Solve:          = 0.0006464 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.019524 seconds
#
# Linear solver (AWWHLA1I__system-execute), solution time 1.974137e-02 (secs)
# Time Integration
# 	2nd order:                 Y4NXFZ96__integrand -    0.0209 [min] /    0.0209 [max] (secs)
# Time Integration - 0.0209495 [min] / 0.0209495 [max] (secs)
# Linear solver (MN5UEGUL__system-execute)
# Linear solver (MN5UEGUL__system-execute), solution time 1.266352e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# Step:    21 Model Time: 4920.7 year dt:    0.0 second (2025-05-21 14:13:40)
# Linear solver (AWWHLA1I__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001426 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0005002 secs / 1 its
#   Pressure Solve:         = 0.003151 secs / 5 its
#   Final V Solve:          = 0.0004258 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.017915 seconds
#
# Linear solver (AWWHLA1I__system-execute), solution time 1.812380e-02 (secs)
# Time Integration
# 	2nd order:                 Y4NXFZ96__integrand -    0.0214 [min] /    0.0214 [max] (secs)
# Time Integration - 0.0214224 [min] / 0.0214224 [max] (secs)
# Linear solver (MN5UEGUL__system-execute)
# Linear solver (MN5UEGUL__system-execute), solution time 1.240977e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# Step:    22 Model Time: 5166.7 year dt:  246.0 year (2025-05-21 14:13:40)
# Linear solver (AWWHLA1I__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001373 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0007837 secs / 1 its
#   Pressure Solve:         = 0.002696 secs / 5 its
#   Final V Solve:          = 0.0004232 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.020383 seconds
#
# Linear solver (AWWHLA1I__system-execute), solution time 2.058453e-02 (secs)
# Time Integration
# 	2nd order:                 Y4NXFZ96__integrand -    0.0222 [min] /    0.0222 [max] (secs)
# Time Integration - 0.022227 [min] / 0.022227 [max] (secs)
# Linear solver (MN5UEGUL__system-execute)
# Linear solver (MN5UEGUL__system-execute), solution time 1.342407e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# Step:    23 Model Time: 5412.7 year dt:  246.0 year (2025-05-21 14:13:41)
# Linear solver (AWWHLA1I__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001354 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0005865 secs / 1 its
#   Pressure Solve:         = 0.003807 secs / 5 its
#   Final V Solve:          = 0.000871 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.019742 seconds
#
# Linear solver (AWWHLA1I__system-execute), solution time 1.995938e-02 (secs)
# Time Integration
# 	2nd order:                 Y4NXFZ96__integrand -    0.0232 [min] /    0.0232 [max] (secs)
# Time Integration - 0.0231901 [min] / 0.0231901 [max] (secs)
# Linear solver (MN5UEGUL__system-execute)
# Linear solver (MN5UEGUL__system-execute), solution time 1.790205e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# Step:    24 Model Time: 5658.8 year dt:  246.0 year (2025-05-21 14:13:41)
# Linear solver (AWWHLA1I__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001394 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0007494 secs / 1 its
#   Pressure Solve:         = 0.003344 secs / 5 its
#   Final V Solve:          = 0.0004745 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.018717 seconds
#
# Linear solver (AWWHLA1I__system-execute), solution time 1.892335e-02 (secs)
# Time Integration
# 	2nd order:                 Y4NXFZ96__integrand -    0.0218 [min] /    0.0218 [max] (secs)
# Time Integration - 0.0218008 [min] / 0.0218008 [max] (secs)
# Linear solver (MN5UEGUL__system-execute)
# Linear solver (MN5UEGUL__system-execute), solution time 1.279551e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# Step:    25 Model Time: 5904.8 year dt:  246.0 year (2025-05-21 14:13:41)
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# Linear solver (AWWHLA1I__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001430 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0009777 secs / 1 its
#   Pressure Solve:         = 0.005955 secs / 5 its
#   Final V Solve:          = 0.0007558 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.022906 seconds
#
# Linear solver (AWWHLA1I__system-execute), solution time 2.312818e-02 (secs)
# Time Integration
# 	2nd order:                 Y4NXFZ96__integrand -    0.0212 [min] /    0.0212 [max] (secs)
# Time Integration - 0.0211914 [min] / 0.0211914 [max] (secs)
# Linear solver (MN5UEGUL__system-execute)
# Linear solver (MN5UEGUL__system-execute), solution time 1.353319e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# Step:    26 Model Time: 6150.8 year dt:  246.0 year (2025-05-21 14:13:41)
# Linear solver (AWWHLA1I__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001358 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0008402 secs / 1 its
#   Pressure Solve:         = 0.004892 secs / 5 its
#   Final V Solve:          = 0.0007605 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.022658 seconds
#
# Linear solver (AWWHLA1I__system-execute), solution time 2.286842e-02 (secs)
# Time Integration
# 	2nd order:                 Y4NXFZ96__integrand -    0.0226 [min] /    0.0226 [max] (secs)
# Time Integration - 0.0226333 [min] / 0.0226333 [max] (secs)
# Linear solver (MN5UEGUL__system-execute)
# Linear solver (MN5UEGUL__system-execute), solution time 1.407532e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# Step:    27 Model Time: 6150.8 year dt:    0.0 second (2025-05-21 14:13:42)
# Linear solver (AWWHLA1I__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001332 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0009947 secs / 1 its
#   Pressure Solve:         = 0.00507 secs / 5 its
#   Final V Solve:          = 0.001357 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.023143 seconds
#
# Linear solver (AWWHLA1I__system-execute), solution time 2.333404e-02 (secs)
# Time Integration
# 	2nd order:                 Y4NXFZ96__integrand -    0.0231 [min] /    0.0231 [max] (secs)
# Time Integration - 0.0230891 [min] / 0.0230891 [max] (secs)
# Linear solver (MN5UEGUL__system-execute)
# Linear solver (MN5UEGUL__system-execute), solution time 1.176490e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# Step:    28 Model Time: 6396.9 year dt:  246.0 year (2025-05-21 14:13:43)
# Linear solver (AWWHLA1I__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001373 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.000981 secs / 1 its
#   Pressure Solve:         = 0.004936 secs / 5 its
#   Final V Solve:          = 0.0006039 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.021594 seconds
#
# Linear solver (AWWHLA1I__system-execute), solution time 2.179347e-02 (secs)
# Time Integration
# 	2nd order:                 Y4NXFZ96__integrand -    0.0225 [min] /    0.0225 [max] (secs)
# Time Integration - 0.02248 [min] / 0.02248 [max] (secs)
# Linear solver (MN5UEGUL__system-execute)
# Linear solver (MN5UEGUL__system-execute), solution time 1.264358e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# Step:    29 Model Time: 6642.9 year dt:  246.0 year (2025-05-21 14:13:43)
# Linear solver (AWWHLA1I__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001342 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0009602 secs / 1 its
#   Pressure Solve:         = 0.00393 secs / 5 its
#   Final V Solve:          = 0.0004447 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.019798 seconds
#
# Linear solver (AWWHLA1I__system-execute), solution time 1.999627e-02 (secs)
# Time Integration
# 	2nd order:                 Y4NXFZ96__integrand -    0.0221 [min] /    0.0221 [max] (secs)
# Time Integration - 0.0221373 [min] / 0.0221373 [max] (secs)
# Linear solver (MN5UEGUL__system-execute)
# Linear solver (MN5UEGUL__system-execute), solution time 1.327638e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# Step:    30 Model Time: 6888.9 year dt:  246.0 year (2025-05-21 14:13:43)
# Linear solver (AWWHLA1I__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001372 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0008602 secs / 1 its
#   Pressure Solve:         = 0.003723 secs / 5 its
#   Final V Solve:          = 0.0004519 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.021232 seconds
#
# Linear solver (AWWHLA1I__system-execute), solution time 2.143110e-02 (secs)
# Time Integration
# 	2nd order:                 Y4NXFZ96__integrand -    0.0240 [min] /    0.0240 [max] (secs)
# Time Integration - 0.0240095 [min] / 0.0240095 [max] (secs)
# Linear solver (MN5UEGUL__system-execute)
# Linear solver (MN5UEGUL__system-execute), solution time 1.380184e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# Step:    31 Model Time: 7135.0 year dt:  246.0 year (2025-05-21 14:13:43)
# Linear solver (AWWHLA1I__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001679 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0008556 secs / 1 its
#   Pressure Solve:         = 0.004851 secs / 5 its
#   Final V Solve:          = 0.0008918 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.022620 seconds
#
# Linear solver (AWWHLA1I__system-execute), solution time 2.287722e-02 (secs)
# Time Integration
# 	2nd order:                 Y4NXFZ96__integrand -    0.0228 [min] /    0.0228 [max] (secs)
# Time Integration - 0.0228338 [min] / 0.0228338 [max] (secs)
# Linear solver (MN5UEGUL__system-execute)
# Linear solver (MN5UEGUL__system-execute), solution time 1.399549e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# Step:    32 Model Time: 7381.0 year dt:  246.0 year (2025-05-21 14:13:44)
# Linear solver (AWWHLA1I__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001394 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0005176 secs / 1 its
#   Pressure Solve:         = 0.003301 secs / 5 its
#   Final V Solve:          = 0.0006227 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.021311 seconds
#
# Linear solver (AWWHLA1I__system-execute), solution time 2.151992e-02 (secs)
# Time Integration
# 	2nd order:                 Y4NXFZ96__integrand -    0.0214 [min] /    0.0214 [max] (secs)
# Time Integration - 0.0214486 [min] / 0.0214486 [max] (secs)
# Linear solver (MN5UEGUL__system-execute)
# Linear solver (MN5UEGUL__system-execute), solution time 1.308053e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# Step:    33 Model Time: 7381.0 year dt:    0.0 second (2025-05-21 14:13:44)
# Linear solver (AWWHLA1I__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001478 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0008598 secs / 1 its
#   Pressure Solve:         = 0.003775 secs / 5 its
#   Final V Solve:          = 0.0008688 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.020825 seconds
#
# Linear solver (AWWHLA1I__system-execute), solution time 2.104313e-02 (secs)
# Time Integration
# 	2nd order:                 Y4NXFZ96__integrand -    0.0231 [min] /    0.0231 [max] (secs)
# Time Integration - 0.0231342 [min] / 0.0231342 [max] (secs)
# Linear solver (MN5UEGUL__system-execute)
# Linear solver (MN5UEGUL__system-execute), solution time 1.374459e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# Step:    34 Model Time: 7627.0 year dt:  246.0 year (2025-05-21 14:13:45)
# Linear solver (AWWHLA1I__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001339 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0006549 secs / 1 its
#   Pressure Solve:         = 0.004844 secs / 5 its
#   Final V Solve:          = 0.0008129 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.021599 seconds
#
# Linear solver (AWWHLA1I__system-execute), solution time 2.182647e-02 (secs)
# Time Integration
# 	2nd order:                 Y4NXFZ96__integrand -    0.0242 [min] /    0.0242 [max] (secs)
# Time Integration - 0.0241938 [min] / 0.0241938 [max] (secs)
# Linear solver (MN5UEGUL__system-execute)
# Linear solver (MN5UEGUL__system-execute), solution time 1.627158e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# Step:    35 Model Time: 7873.1 year dt:  246.0 year (2025-05-21 14:13:45)
# Linear solver (AWWHLA1I__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001451 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.001033 secs / 1 its
#   Pressure Solve:         = 0.005307 secs / 5 its
#   Final V Solve:          = 0.0008985 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.023276 seconds
#
# Linear solver (AWWHLA1I__system-execute), solution time 2.351160e-02 (secs)
# Time Integration
# 	2nd order:                 Y4NXFZ96__integrand -    0.0218 [min] /    0.0218 [max] (secs)
# Time Integration - 0.0218389 [min] / 0.0218389 [max] (secs)
# Linear solver (MN5UEGUL__system-execute)
# Linear solver (MN5UEGUL__system-execute), solution time 1.283965e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# Step:    36 Model Time: 8119.1 year dt:  246.0 year (2025-05-21 14:13:45)
# Linear solver (AWWHLA1I__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001438 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0005864 secs / 1 its
#   Pressure Solve:         = 0.002667 secs / 5 its
#   Final V Solve:          = 0.0005305 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.017492 seconds
#
# Linear solver (AWWHLA1I__system-execute), solution time 1.770933e-02 (secs)
# Time Integration
# 	2nd order:                 Y4NXFZ96__integrand -    0.0239 [min] /    0.0239 [max] (secs)
# Time Integration - 0.0238951 [min] / 0.0238951 [max] (secs)
# Linear solver (MN5UEGUL__system-execute)
# Linear solver (MN5UEGUL__system-execute), solution time 1.887098e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# Step:    37 Model Time: 8365.1 year dt:  246.0 year (2025-05-21 14:13:46)
# Linear solver (AWWHLA1I__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001372 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0008665 secs / 1 its
#   Pressure Solve:         = 0.003975 secs / 5 its
#   Final V Solve:          = 0.0004471 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.020286 seconds
#
# Linear solver (AWWHLA1I__system-execute), solution time 2.049188e-02 (secs)
# Time Integration
# 	2nd order:                 Y4NXFZ96__integrand -    0.0218 [min] /    0.0218 [max] (secs)
# Time Integration - 0.0218228 [min] / 0.0218228 [max] (secs)
# Linear solver (MN5UEGUL__system-execute)
# Linear solver (MN5UEGUL__system-execute), solution time 1.323371e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# Step:    38 Model Time: 8611.2 year dt:  246.0 year (2025-05-21 14:13:46)
# Linear solver (AWWHLA1I__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001388 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0008221 secs / 1 its
#   Pressure Solve:         = 0.00436 secs / 5 its
#   Final V Solve:          = 0.0008007 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.021022 seconds
#
# Linear solver (AWWHLA1I__system-execute), solution time 2.123687e-02 (secs)
# Time Integration
# 	2nd order:                 Y4NXFZ96__integrand -    0.0213 [min] /    0.0213 [max] (secs)
# Time Integration - 0.0213473 [min] / 0.0213473 [max] (secs)
# Linear solver (MN5UEGUL__system-execute)
# Linear solver (MN5UEGUL__system-execute), solution time 1.202284e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# Step:    39 Model Time: 8611.2 year dt:    0.0 second (2025-05-21 14:13:47)
# Linear solver (AWWHLA1I__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001461 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.000888 secs / 1 its
#   Pressure Solve:         = 0.004738 secs / 5 its
#   Final V Solve:          = 0.000777 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.022072 seconds
#
# Linear solver (AWWHLA1I__system-execute), solution time 2.231311e-02 (secs)
# Time Integration
# 	2nd order:                 Y4NXFZ96__integrand -    0.0218 [min] /    0.0218 [max] (secs)
# Time Integration - 0.0218046 [min] / 0.0218046 [max] (secs)
# Linear solver (MN5UEGUL__system-execute)
# Linear solver (MN5UEGUL__system-execute), solution time 1.287736e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# ...
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# Step:   394 Model Time: 95461.0 year dt:  246.0 year (2025-05-21 14:16:02)
# Linear solver (AWWHLA1I__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001194 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0007912 secs / 1 its
#   Pressure Solve:         = 0.002869 secs / 5 its
#   Final V Solve:          = 0.0004136 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.019050 seconds
#
# Linear solver (AWWHLA1I__system-execute), solution time 1.926159e-02 (secs)
# Time Integration
# 	2nd order:                 Y4NXFZ96__integrand -    0.0212 [min] /    0.0212 [max] (secs)
# Time Integration - 0.0211804 [min] / 0.0211804 [max] (secs)
# Linear solver (MN5UEGUL__system-execute)
# Linear solver (MN5UEGUL__system-execute), solution time 1.239507e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# Step:   395 Model Time: 95707.0 year dt:  246.0 year (2025-05-21 14:16:02)
# Linear solver (AWWHLA1I__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001248 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.000752 secs / 1 its
#   Pressure Solve:         = 0.004188 secs / 5 its
#   Final V Solve:          = 0.0007361 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.021225 seconds
#
# Linear solver (AWWHLA1I__system-execute), solution time 2.147311e-02 (secs)
# Time Integration
# 	2nd order:                 Y4NXFZ96__integrand -    0.0224 [min] /    0.0224 [max] (secs)
# Time Integration - 0.0223977 [min] / 0.0223977 [max] (secs)
# Linear solver (MN5UEGUL__system-execute)
# Linear solver (MN5UEGUL__system-execute), solution time 1.343757e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# Step:   396 Model Time: 95953.0 year dt:  246.0 year (2025-05-21 14:16:03)
# Linear solver (AWWHLA1I__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001384 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0007888 secs / 1 its
#   Pressure Solve:         = 0.004711 secs / 5 its
#   Final V Solve:          = 0.0007915 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.021721 seconds
#
# Linear solver (AWWHLA1I__system-execute), solution time 2.197572e-02 (secs)
# Time Integration
# 	2nd order:                 Y4NXFZ96__integrand -    0.0213 [min] /    0.0213 [max] (secs)
# Time Integration - 0.0213538 [min] / 0.0213538 [max] (secs)
# Linear solver (MN5UEGUL__system-execute)
# Linear solver (MN5UEGUL__system-execute), solution time 1.254775e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# Step:   397 Model Time: 96199.1 year dt:  246.0 year (2025-05-21 14:16:03)
# Linear solver (AWWHLA1I__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001418 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0005245 secs / 1 its
#   Pressure Solve:         = 0.002538 secs / 5 its
#   Final V Solve:          = 0.0004175 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.017598 seconds
#
# Linear solver (AWWHLA1I__system-execute), solution time 1.784620e-02 (secs)
# Time Integration
# 	2nd order:                 Y4NXFZ96__integrand -    0.0228 [min] /    0.0228 [max] (secs)
# Time Integration - 0.0227833 [min] / 0.0227833 [max] (secs)
# Linear solver (MN5UEGUL__system-execute)
# Linear solver (MN5UEGUL__system-execute), solution time 1.968091e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# Step:   398 Model Time: 96445.1 year dt:  246.0 year (2025-05-21 14:16:03)
# Linear solver (AWWHLA1I__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001236 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0005783 secs / 1 its
#   Pressure Solve:         = 0.002669 secs / 5 its
#   Final V Solve:          = 0.0008725 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.016217 seconds
#
# Linear solver (AWWHLA1I__system-execute), solution time 1.646096e-02 (secs)
# Time Integration
# 	2nd order:                 Y4NXFZ96__integrand -    0.0213 [min] /    0.0213 [max] (secs)
# Time Integration - 0.021316 [min] / 0.021316 [max] (secs)
# Linear solver (MN5UEGUL__system-execute)
# Linear solver (MN5UEGUL__system-execute), solution time 1.267109e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# Step:   399 Model Time: 96691.1 year dt:  246.0 year (2025-05-21 14:16:03)
# Linear solver (AWWHLA1I__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001239 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0009853 secs / 1 its
#   Pressure Solve:         = 0.004278 secs / 5 its
#   Final V Solve:          = 0.0007026 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.020994 seconds
#
# Linear solver (AWWHLA1I__system-execute), solution time 2.123616e-02 (secs)
# Time Integration
# 	2nd order:                 Y4NXFZ96__integrand -    0.0222 [min] /    0.0222 [max] (secs)
# Time Integration - 0.0222033 [min] / 0.0222033 [max] (secs)
# Linear solver (MN5UEGUL__system-execute)
# Linear solver (MN5UEGUL__system-execute), solution time 1.931040e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# Step:   400 Model Time: 96937.2 year dt:  246.0 year (2025-05-21 14:16:04)
# Linear solver (AWWHLA1I__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001299 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0008356 secs / 1 its
#   Pressure Solve:         = 0.004521 secs / 5 its
#   Final V Solve:          = 0.0006991 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.021142 seconds
#
# Linear solver (AWWHLA1I__system-execute), solution time 2.139948e-02 (secs)
# Time Integration
# 	2nd order:                 Y4NXFZ96__integrand -    0.0212 [min] /    0.0212 [max] (secs)
# Time Integration - 0.0212696 [min] / 0.0212696 [max] (secs)
# Linear solver (MN5UEGUL__system-execute)
# Linear solver (MN5UEGUL__system-execute), solution time 1.254412e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# Step:   401 Model Time: 97183.2 year dt:  246.0 year (2025-05-21 14:16:04)
# Linear solver (AWWHLA1I__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001366 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0008544 secs / 1 its
#   Pressure Solve:         = 0.003844 secs / 5 its
#   Final V Solve:          = 0.000429 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.019952 seconds
#
# Linear solver (AWWHLA1I__system-execute), solution time 2.018766e-02 (secs)
# Time Integration
# 	2nd order:                 Y4NXFZ96__integrand -    0.0224 [min] /    0.0224 [max] (secs)
# Time Integration - 0.0224656 [min] / 0.0224656 [max] (secs)
# Linear solver (MN5UEGUL__system-execute)
# Linear solver (MN5UEGUL__system-execute), solution time 1.282963e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# Step:   402 Model Time: 97429.2 year dt:  246.0 year (2025-05-21 14:16:05)
# Linear solver (AWWHLA1I__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001417 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0005054 secs / 1 its
#   Pressure Solve:         = 0.003843 secs / 5 its
#   Final V Solve:          = 0.0007855 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.020021 seconds
#
# Linear solver (AWWHLA1I__system-execute), solution time 2.028210e-02 (secs)
# Time Integration
# 	2nd order:                 Y4NXFZ96__integrand -    0.0211 [min] /    0.0211 [max] (secs)
# Time Integration - 0.0211277 [min] / 0.0211277 [max] (secs)
# Linear solver (MN5UEGUL__system-execute)
# Linear solver (MN5UEGUL__system-execute), solution time 1.277006e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# Step:   403 Model Time: 97675.3 year dt:  246.0 year (2025-05-21 14:16:05)
# Linear solver (AWWHLA1I__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001411 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0009382 secs / 1 its
#   Pressure Solve:         = 0.004102 secs / 5 its
#   Final V Solve:          = 0.0007931 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.021048 seconds
#
# Linear solver (AWWHLA1I__system-execute), solution time 2.129963e-02 (secs)
# Time Integration
# 	2nd order:                 Y4NXFZ96__integrand -    0.0232 [min] /    0.0232 [max] (secs)
# Time Integration - 0.0231799 [min] / 0.0231799 [max] (secs)
# Linear solver (MN5UEGUL__system-execute)
# Linear solver (MN5UEGUL__system-execute), solution time 1.388362e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# Step:   404 Model Time: 97921.3 year dt:  246.0 year (2025-05-21 14:16:05)
# Linear solver (AWWHLA1I__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001230 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0008306 secs / 1 its
#   Pressure Solve:         = 0.003446 secs / 5 its
#   Final V Solve:          = 0.0005094 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.021728 seconds
#
# Linear solver (AWWHLA1I__system-execute), solution time 2.206771e-02 (secs)
# Time Integration
# 	2nd order:                 Y4NXFZ96__integrand -    0.0232 [min] /    0.0232 [max] (secs)
# Time Integration - 0.0232732 [min] / 0.0232732 [max] (secs)
# Linear solver (MN5UEGUL__system-execute)
# Linear solver (MN5UEGUL__system-execute), solution time 1.233693e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# Step:   405 Model Time: 98167.3 year dt:  246.0 year (2025-05-21 14:16:05)
# Linear solver (AWWHLA1I__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001344 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0009052 secs / 1 its
#   Pressure Solve:         = 0.00429 secs / 5 its
#   Final V Solve:          = 0.000727 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.021808 seconds
#
# Linear solver (AWWHLA1I__system-execute), solution time 2.206086e-02 (secs)
# Time Integration
# 	2nd order:                 Y4NXFZ96__integrand -    0.0217 [min] /    0.0217 [max] (secs)
# Time Integration - 0.0217219 [min] / 0.0217219 [max] (secs)
# Linear solver (MN5UEGUL__system-execute)
# Linear solver (MN5UEGUL__system-execute), solution time 1.349612e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# Step:   406 Model Time: 98413.4 year dt:  246.0 year (2025-05-21 14:16:06)
# Linear solver (AWWHLA1I__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001365 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0004871 secs / 1 its
#   Pressure Solve:         = 0.002756 secs / 5 its
#   Final V Solve:          = 0.0004701 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.017422 seconds
#
# Linear solver (AWWHLA1I__system-execute), solution time 1.766905e-02 (secs)
# Time Integration
# 	2nd order:                 Y4NXFZ96__integrand -    0.0228 [min] /    0.0228 [max] (secs)
# Time Integration - 0.0228479 [min] / 0.0228479 [max] (secs)
# Linear solver (MN5UEGUL__system-execute)
# Linear solver (MN5UEGUL__system-execute), solution time 1.314583e-03 (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "EJGSELHU__swarm"
# 	done 33% (834 cells)...
# 	done 67% (1667 cells)...
# 	done 100% (2500 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "EJGSELHU__swarm"
# Step:   407 Model Time: 98413.4 year dt:    0.0 second (2025-05-21 14:16:06)
# 1
