# %%
import underworld as uw
import math
from underworld import function as fn
import numpy as np
import os

from underworld import UWGeodynamics as GEO
u = GEO.UnitRegistry
ndim = GEO.non_dimensionalise
dimen = GEO.dimensionalise

comm = uw.mpi.comm
rank = uw.mpi.rank
size = uw.mpi.size

from _freesurface_ALEIB import FreeSurfaceProcessor_ALEIB
# Out:
# loaded rc file /home/nl/anaconda3/envs/uw2/lib/python3.11/site-packages/underworld/UWGeodynamics/uwgeo-data/uwgeodynamicsrc

# %%
# solver parameters
GEO.rcParams["initial.nonlinear.tolerance"] = 1e-3
GEO.rcParams['initial.nonlinear.max.iterations'] = 100
GEO.rcParams["nonlinear.tolerance"] = 1e-3
GEO.rcParams['nonlinear.max.iterations'] = 100
GEO.rcParams["popcontrol.particles.per.cell.2D"] = 16
GEO.rcParams["swarm.particles.per.cell.2D"] = 16
GEO.rcParams["surface.pressure.normalization"] = True
GEO.rcParams["pressure.smoothing"] = True
GEO.rcParams["popcontrol.split.threshold"] = 0.1

# %%
# scaling 3: vel
half_rate = 1.0 * u.centimeter / u.year
model_length = 500. * u.kilometer
gravity = 9.81 * u.meter / u.second**2
bodyforce = 3300 * u.kilogram / u.metre**3 *gravity 

KL = model_length
Kt = KL / half_rate
KM = bodyforce * KL**2 * Kt**2

GEO.scaling_coefficients["[length]"] = KL
GEO.scaling_coefficients["[time]"] = Kt
GEO.scaling_coefficients["[mass]"]= KM

# %%
xmin, xmax = ndim(-250 * u.kilometer), ndim(250 * u.kilometer)
ymin, ymax = ndim(-500 * u.kilometer), ndim(100 * u.kilometer)
yint = 0.
 
dy = ndim(500 * u.kilometer)/50
dx = dy
xRes,yRes = int((xmax-xmin)/dx),int((ymax-ymin)/dy)
yResa,yResb =int((ymax-yint)/dy),int((yint-ymin)/dy)

#tRatio =  int(sys.argv[1])
tRatio = 100
save_every = 1
use_fssa = False
if use_fssa:
    outputPath = "op_Ex_2DTopoRelax_FreeSurf_Eulerian_withFSSA0.5_yres{:n}_tRatio{:n}_Swarm_uwg".format(yRes,tRatio)
    save_every = 1
else:
    outputPath = "op_Ex_2DTopoRelax_FreeSurf_Eulerian_noFSSA_yres{:n}_tRatio{:n}_Swarm_uwg".format(yRes,tRatio)
    save_every = 5

# %%
Model = GEO.Model(elementRes=(xRes, yRes),
                  minCoord=(xmin,ymin),
                  maxCoord=(xmax, ymax),
                  gravity=(0.0, -gravity),
                  periodic=(True, False))
Model.outputDir= outputPath
Model.minStrainRate = 1e-18 / u.second
# Out:
# 	Global element size: 50x60
# 	Local offset of rank 0: 0x0
# 	Local range of rank 0: 50x60
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"

# %%
wRatio = 1
D = np.abs(ymin)
Lambda = D/wRatio
k = 2.0 * np.pi / Lambda
mu0 = ndim(1e21  * u.pascal * u.second)
g = ndim(gravity)
rho0 = ndim(3300* u.kilogram / u.metre**3)
drho = rho0-0.
w_m = ndim(10*u.kilometer)

tau0 = 2*k*mu0/drho/g
tau = (D*k+np.sinh(D*k)*np.cosh(D*k))/(np.sinh(D*k)**2)*tau0

def perturbation(x):
    return w_m * np.cos(2.*np.pi*(x)/Lambda)

fn_coord = fn.input()
deform_fn = w_m * fn.math.cos(2.*np.pi*fn_coord[0]/Lambda)

# def get_analytical(x0,load_time):
#     #tau = (D*k+np.sinh(D*k)*np.cosh(D*k))/(np.sinh(D*k)**2)*tau0
#     #A = -F0/k/tau0
#     #B = -F0/k/tau
#     #C = F0/tau
#     #E = F0/tau/np.tanh(D*k)
#     #phi = np.sin(k*x)*np.exp(-tmax/tau)*(A*np.sinh(k*z)+B*np.cosh(k*z)+C*z*np.sinh(k*z)+E*z*np.cosh(k*z))
#     w = w_m*np.exp(-load_time/tau)
#     return w

max_time =  tau*4
dt_set = tau/tRatio

# %%
materialAShape = fn_coord[1] > deform_fn #GEO.shapes.Layer(top=Model.top, bottom=Model.bottom)
materialMShape = fn_coord[1] <= deform_fn

materialA = Model.add_material(name="Air", shape=materialAShape)
materialM = Model.add_material(name="Mantle", shape=materialMShape)

# %%
npoints = xRes*2+1
coords = np.zeros((npoints,2))
coords[:,0] = np.linspace(xmin,xmax,npoints)
coords[:,1] = perturbation(coords[:,0])

Model.add_passive_tracers('surf',vertices=coords)

# %%
# if uw.mpi.rank == 0:
#     from underworld import visualisation as vis
#     fig_res = (500,500)

#     Fig = vis.Figure(resolution=fig_res,rulers=False,margin = 20,rulerticks=7,quality=2,clipmap=False) 
#     Fig.Points(Model.swarm, Model.materialField,fn_size=2.0,discrete=True,colourBar=True,colours='blue orange')
#     Fig.Mesh(Model.mesh)
#     Fig.show()
#     Fig.save("Modelsetup.png")

# %%
# Model.maxViscosity = 1e21 * u.pascal * u.second
# Model.minViscosity = 1e18 * u.pascal * u.second

materialA.viscosity = 1e18 * u.pascal * u.second
materialM.viscosity = 1e21 * u.pascal * u.second

materialA.density = 0.
materialM.density = 3300 * u.kilogram / u.metre**3

# %%
Model.set_velocityBCs(left=[0.,None],right=[0,None],bottom=[0.,0.], top=[None, 0.])

Model.init_model()

Model.solver.set_inner_method("mumps")
Model.solver.set_penalty(1e3)
# Out:
# /home/nl/anaconda3/envs/uw2/lib/python3.11/site-packages/underworld/UWGeodynamics/_model.py:1595: UserWarning: Skipping the steady state calculation: No diffusivity variable defined on Model
#   warnings.warn("Skipping the steady state calculation: No diffusivity variable defined on Model")

# %%
if use_fssa:
    Model._fssa_factor = 0.5

# %%
max_time = dimen(tau*4,u.kiloyear)
dt_set = dimen(tau/tRatio,u.kiloyear)
checkpoint_interval = dt_set*save_every 

Model.run_for(max_time, checkpoint_interval=checkpoint_interval,dt=dt_set)
# Out:
# Options:  -Q22_pc_type gkgdiag -force_correction True -ksp_type bsscr -pc_type none -ksp_k2_type NULL -rescale_equations False -remove_constant_pressure_null_space False -change_backsolve False -change_A11rhspresolve False -restore_K False -A11_ksp_type preonly -A11_pc_type lu -A11_pc_factor_mat_solver_type mumps -scr_ksp_type fgmres -scr_ksp_rtol 1e-05 -A11_mg_active False
# Linear solver (1DMC7469__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001787 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.001148 secs / 1 its
#   Pressure Solve:         = 0.005254 secs / 5 its
#   Final V Solve:          = 0.000505 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.034455 seconds
#
# Linear solver (1DMC7469__system-execute), solution time 3.491123e-02 (secs)
# Time Integration
# 	2nd order:                 5Q9T0C41__integrand -    0.0160 [min] /    0.0160 [max] (secs)
# Time Integration - 0.0160363 [min] / 0.0160363 [max] (secs)
# Time Integration
# 	2nd order:                 ZH8F1NRD__integrand -    0.0000 [min] /    0.0000 [max] (secs)
# Time Integration - 4.6608e-05 [min] / 4.6608e-05 [max] (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"
# Step:     1 Model Time:  246.0 year dt:  246.0 year (2025-05-21 14:05:59)
# Linear solver (1DMC7469__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001511 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0006242 secs / 1 its
#   Pressure Solve:         = 0.003142 secs / 5 its
#   Final V Solve:          = 0.0005082 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.028587 seconds
#
# Linear solver (1DMC7469__system-execute), solution time 2.876355e-02 (secs)
# Time Integration
# 	2nd order:                 5Q9T0C41__integrand -    0.0172 [min] /    0.0172 [max] (secs)
# Time Integration - 0.0171971 [min] / 0.0171971 [max] (secs)
# Time Integration
# 	2nd order:                 ZH8F1NRD__integrand -    0.0000 [min] /    0.0000 [max] (secs)
# Time Integration - 4.353e-05 [min] / 4.353e-05 [max] (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"
# Step:     2 Model Time:  492.1 year dt:  246.0 year (2025-05-21 14:05:59)
# Linear solver (1DMC7469__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001516 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.001109 secs / 1 its
#   Pressure Solve:         = 0.005284 secs / 5 its
#   Final V Solve:          = 0.0008318 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.038721 seconds
#
# Linear solver (1DMC7469__system-execute), solution time 3.891385e-02 (secs)
# Time Integration
# 	2nd order:                 5Q9T0C41__integrand -    0.0171 [min] /    0.0171 [max] (secs)
# Time Integration - 0.0170939 [min] / 0.0170939 [max] (secs)
# Time Integration
# 	2nd order:                 ZH8F1NRD__integrand -    0.0001 [min] /    0.0001 [max] (secs)
# Time Integration - 7.646e-05 [min] / 7.646e-05 [max] (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"
# Step:     3 Model Time:  738.1 year dt:  246.0 year (2025-05-21 14:06:00)
# Linear solver (1DMC7469__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001439 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0006572 secs / 1 its
#   Pressure Solve:         = 0.004083 secs / 5 its
#   Final V Solve:          = 0.0006791 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.030818 seconds
#
# Linear solver (1DMC7469__system-execute), solution time 3.100795e-02 (secs)
# Time Integration
# 	2nd order:                 5Q9T0C41__integrand -    0.0180 [min] /    0.0180 [max] (secs)
# Time Integration - 0.018026 [min] / 0.018026 [max] (secs)
# Time Integration
# 	2nd order:                 ZH8F1NRD__integrand -    0.0000 [min] /    0.0000 [max] (secs)
# Time Integration - 5.0766e-05 [min] / 5.0766e-05 [max] (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"
# Step:     4 Model Time:  984.1 year dt:  246.0 year (2025-05-21 14:06:00)
# Linear solver (1DMC7469__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001555 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.001042 secs / 1 its
#   Pressure Solve:         = 0.00561 secs / 5 its
#   Final V Solve:          = 0.0009765 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.033443 seconds
#
# Linear solver (1DMC7469__system-execute), solution time 3.364015e-02 (secs)
# Time Integration
# 	2nd order:                 5Q9T0C41__integrand -    0.0182 [min] /    0.0182 [max] (secs)
# Time Integration - 0.0182197 [min] / 0.0182197 [max] (secs)
# Time Integration
# 	2nd order:                 ZH8F1NRD__integrand -    0.0000 [min] /    0.0000 [max] (secs)
# Time Integration - 5.2791e-05 [min] / 5.2791e-05 [max] (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"
# Step:     5 Model Time: 1230.2 year dt:  246.0 year (2025-05-21 14:06:01)
# Linear solver (1DMC7469__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001470 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.001067 secs / 1 its
#   Pressure Solve:         = 0.005069 secs / 5 its
#   Final V Solve:          = 0.0008978 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.032099 seconds
#
# Linear solver (1DMC7469__system-execute), solution time 3.229530e-02 (secs)
# Time Integration
# 	2nd order:                 5Q9T0C41__integrand -    0.0174 [min] /    0.0174 [max] (secs)
# Time Integration - 0.0174083 [min] / 0.0174083 [max] (secs)
# Time Integration
# 	2nd order:                 ZH8F1NRD__integrand -    0.0000 [min] /    0.0000 [max] (secs)
# Time Integration - 5.2666e-05 [min] / 5.2666e-05 [max] (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"
# Step:     6 Model Time: 1476.2 year dt:  246.0 year (2025-05-21 14:06:01)
# Linear solver (1DMC7469__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001514 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.001029 secs / 1 its
#   Pressure Solve:         = 0.005309 secs / 5 its
#   Final V Solve:          = 0.0009881 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.032524 seconds
#
# Linear solver (1DMC7469__system-execute), solution time 3.273040e-02 (secs)
# Time Integration
# 	2nd order:                 5Q9T0C41__integrand -    0.0181 [min] /    0.0181 [max] (secs)
# Time Integration - 0.0181116 [min] / 0.0181116 [max] (secs)
# Time Integration
# 	2nd order:                 ZH8F1NRD__integrand -    0.0000 [min] /    0.0000 [max] (secs)
# Time Integration - 4.8278e-05 [min] / 4.8278e-05 [max] (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"
# Step:     7 Model Time: 1722.2 year dt:  246.0 year (2025-05-21 14:06:01)
# Linear solver (1DMC7469__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001487 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.001003 secs / 1 its
#   Pressure Solve:         = 0.003546 secs / 5 its
#   Final V Solve:          = 0.001055 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.030290 seconds
#
# Linear solver (1DMC7469__system-execute), solution time 3.050693e-02 (secs)
# Time Integration
# 	2nd order:                 5Q9T0C41__integrand -    0.0177 [min] /    0.0177 [max] (secs)
# Time Integration - 0.0177225 [min] / 0.0177225 [max] (secs)
# Time Integration
# Step:     8 Model Time: 1968.3 year dt:  246.0 year (2025-05-21 14:06:01)
# 	2nd order:                 ZH8F1NRD__integrand -    0.0000 [min] /    0.0000 [max] (secs)
# Time Integration - 5.4767e-05 [min] / 5.4767e-05 [max] (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"
# Linear solver (1DMC7469__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001518 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.001133 secs / 1 its
#   Pressure Solve:         = 0.004981 secs / 5 its
#   Final V Solve:          = 0.0006513 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.032637 seconds
#
# Linear solver (1DMC7469__system-execute), solution time 3.282264e-02 (secs)
# Time Integration
# 	2nd order:                 5Q9T0C41__integrand -    0.0178 [min] /    0.0178 [max] (secs)
# Time Integration - 0.0178282 [min] / 0.0178282 [max] (secs)
# Time Integration
# 	2nd order:                 ZH8F1NRD__integrand -    0.0000 [min] /    0.0000 [max] (secs)
# Time Integration - 4.7826e-05 [min] / 4.7826e-05 [max] (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"
# Step:     9 Model Time: 2214.3 year dt:  246.0 year (2025-05-21 14:06:02)
# Linear solver (1DMC7469__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001491 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0009768 secs / 1 its
#   Pressure Solve:         = 0.005058 secs / 5 its
#   Final V Solve:          = 0.0009323 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.032554 seconds
#
# Linear solver (1DMC7469__system-execute), solution time 3.275193e-02 (secs)
# Time Integration
# 	2nd order:                 5Q9T0C41__integrand -    0.0178 [min] /    0.0178 [max] (secs)
# Time Integration - 0.017793 [min] / 0.017793 [max] (secs)
# Time Integration
# 	2nd order:                 ZH8F1NRD__integrand -    0.0000 [min] /    0.0000 [max] (secs)
# Time Integration - 4.5826e-05 [min] / 4.5826e-05 [max] (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"
# Step:    10 Model Time: 2460.3 year dt:  246.0 year (2025-05-21 14:06:02)
# Linear solver (1DMC7469__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001534 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.001048 secs / 1 its
#   Pressure Solve:         = 0.005949 secs / 5 its
#   Final V Solve:          = 0.00085 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.035357 seconds
#
# Linear solver (1DMC7469__system-execute), solution time 3.557691e-02 (secs)
# Time Integration
# 	2nd order:                 5Q9T0C41__integrand -    0.0180 [min] /    0.0180 [max] (secs)
# Time Integration - 0.0179886 [min] / 0.0179886 [max] (secs)
# Time Integration
# 	2nd order:                 ZH8F1NRD__integrand -    0.0000 [min] /    0.0000 [max] (secs)
# Time Integration - 5.5667e-05 [min] / 5.5667e-05 [max] (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"
# Step:    11 Model Time: 2706.4 year dt:  246.0 year (2025-05-21 14:06:02)
# Linear solver (1DMC7469__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001684 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.001036 secs / 1 its
#   Pressure Solve:         = 0.005055 secs / 5 its
#   Final V Solve:          = 0.0009706 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.033520 seconds
#
# Linear solver (1DMC7469__system-execute), solution time 3.373972e-02 (secs)
# Time Integration
# 	2nd order:                 5Q9T0C41__integrand -    0.0191 [min] /    0.0191 [max] (secs)
# Time Integration - 0.0191047 [min] / 0.0191047 [max] (secs)
# Time Integration
# 	2nd order:                 ZH8F1NRD__integrand -    0.0000 [min] /    0.0000 [max] (secs)
# Time Integration - 4.6717e-05 [min] / 4.6717e-05 [max] (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"
# Step:    12 Model Time: 2952.4 year dt:  246.0 year (2025-05-21 14:06:03)
# Linear solver (1DMC7469__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001678 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.001042 secs / 1 its
#   Pressure Solve:         = 0.005904 secs / 5 its
#   Final V Solve:          = 0.00094 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.036922 seconds
#
# Linear solver (1DMC7469__system-execute), solution time 3.714212e-02 (secs)
# Time Integration
# 	2nd order:                 5Q9T0C41__integrand -    0.0179 [min] /    0.0179 [max] (secs)
# Time Integration - 0.0178999 [min] / 0.0178999 [max] (secs)
# Time Integration
# 	2nd order:                 ZH8F1NRD__integrand -    0.0000 [min] /    0.0000 [max] (secs)
# Time Integration - 4.4615e-05 [min] / 4.4615e-05 [max] (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"
# Step:    13 Model Time: 3198.4 year dt:  246.0 year (2025-05-21 14:06:03)
# Linear solver (1DMC7469__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001443 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0006324 secs / 1 its
#   Pressure Solve:         = 0.00323 secs / 5 its
#   Final V Solve:          = 0.000701 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.027952 seconds
#
# Linear solver (1DMC7469__system-execute), solution time 2.815074e-02 (secs)
# Time Integration
# 	2nd order:                 5Q9T0C41__integrand -    0.0180 [min] /    0.0180 [max] (secs)
# Time Integration - 0.0180354 [min] / 0.0180354 [max] (secs)
# Time Integration
# 	2nd order:                 ZH8F1NRD__integrand -    0.0000 [min] /    0.0000 [max] (secs)
# Time Integration - 4.6299e-05 [min] / 4.6299e-05 [max] (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"
# Step:    14 Model Time: 3444.5 year dt:  246.0 year (2025-05-21 14:06:03)
# Linear solver (1DMC7469__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001525 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.00101 secs / 1 its
#   Pressure Solve:         = 0.005678 secs / 5 its
#   Final V Solve:          = 0.0009486 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.032781 seconds
#
# Linear solver (1DMC7469__system-execute), solution time 3.298210e-02 (secs)
# Time Integration
# 	2nd order:                 5Q9T0C41__integrand -    0.0179 [min] /    0.0179 [max] (secs)
# Time Integration - 0.0179388 [min] / 0.0179388 [max] (secs)
# Time Integration
# 	2nd order:                 ZH8F1NRD__integrand -    0.0000 [min] /    0.0000 [max] (secs)
# Time Integration - 5.1683e-05 [min] / 5.1683e-05 [max] (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"
# Step:    15 Model Time: 3690.5 year dt:  246.0 year (2025-05-21 14:06:04)
# Linear solver (1DMC7469__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001461 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0006105 secs / 1 its
#   Pressure Solve:         = 0.003048 secs / 5 its
#   Final V Solve:          = 0.00079 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.027531 seconds
#
# Linear solver (1DMC7469__system-execute), solution time 2.772205e-02 (secs)
# Time Integration
# 	2nd order:                 5Q9T0C41__integrand -    0.0178 [min] /    0.0178 [max] (secs)
# Time Integration - 0.0178141 [min] / 0.0178141 [max] (secs)
# Time Integration
# 	2nd order:                 ZH8F1NRD__integrand -    0.0000 [min] /    0.0000 [max] (secs)
# Time Integration - 4.4942e-05 [min] / 4.4942e-05 [max] (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"
# Step:    16 Model Time: 3936.5 year dt:  246.0 year (2025-05-21 14:06:04)
# Linear solver (1DMC7469__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001475 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0009768 secs / 1 its
#   Pressure Solve:         = 0.005533 secs / 5 its
#   Final V Solve:          = 0.0005455 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.032883 seconds
#
# Linear solver (1DMC7469__system-execute), solution time 3.307996e-02 (secs)
# Time Integration
# 	2nd order:                 5Q9T0C41__integrand -    0.0180 [min] /    0.0180 [max] (secs)
# Time Integration - 0.0179927 [min] / 0.0179927 [max] (secs)
# Time Integration
# 	2nd order:                 ZH8F1NRD__integrand -    0.0000 [min] /    0.0000 [max] (secs)
# Time Integration - 6.0812e-05 [min] / 6.0812e-05 [max] (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"
# Step:    17 Model Time: 4182.6 year dt:  246.0 year (2025-05-21 14:06:04)
# Linear solver (1DMC7469__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001506 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0009182 secs / 1 its
#   Pressure Solve:         = 0.005292 secs / 5 its
#   Final V Solve:          = 0.001506 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.032281 seconds
#
# Linear solver (1DMC7469__system-execute), solution time 3.250341e-02 (secs)
# Time Integration
# 	2nd order:                 5Q9T0C41__integrand -    0.0184 [min] /    0.0184 [max] (secs)
# Time Integration - 0.0184395 [min] / 0.0184395 [max] (secs)
# Time Integration
# 	2nd order:                 ZH8F1NRD__integrand -    0.0000 [min] /    0.0000 [max] (secs)
# Time Integration - 5.5681e-05 [min] / 5.5681e-05 [max] (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"
# Step:    18 Model Time: 4428.6 year dt:  246.0 year (2025-05-21 14:06:05)
# Linear solver (1DMC7469__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001512 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.001075 secs / 1 its
#   Pressure Solve:         = 0.004601 secs / 5 its
#   Final V Solve:          = 0.0009979 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.032391 seconds
#
# Linear solver (1DMC7469__system-execute), solution time 3.259468e-02 (secs)
# Time Integration
# 	2nd order:                 5Q9T0C41__integrand -    0.0182 [min] /    0.0182 [max] (secs)
# Time Integration - 0.0182609 [min] / 0.0182609 [max] (secs)
# Time Integration
# 	2nd order:                 ZH8F1NRD__integrand -    0.0000 [min] /    0.0000 [max] (secs)
# Time Integration - 5.2359e-05 [min] / 5.2359e-05 [max] (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"
# Step:    19 Model Time: 4674.6 year dt:  246.0 year (2025-05-21 14:06:05)
# Linear solver (1DMC7469__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001558 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.001021 secs / 1 its
#   Pressure Solve:         = 0.004192 secs / 5 its
#   Final V Solve:          = 0.0005202 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.031711 seconds
#
# Linear solver (1DMC7469__system-execute), solution time 3.190348e-02 (secs)
# Time Integration
# 	2nd order:                 5Q9T0C41__integrand -    0.0194 [min] /    0.0194 [max] (secs)
# Time Integration - 0.0194463 [min] / 0.0194463 [max] (secs)
# Time Integration
# 	2nd order:                 ZH8F1NRD__integrand -    0.0000 [min] /    0.0000 [max] (secs)
# Time Integration - 6.0782e-05 [min] / 6.0782e-05 [max] (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"
# Step:    20 Model Time: 4920.7 year dt:  246.0 year (2025-05-21 14:06:05)
# Linear solver (1DMC7469__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001498 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0009818 secs / 1 its
#   Pressure Solve:         = 0.00315 secs / 5 its
#   Final V Solve:          = 0.0005084 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.030254 seconds
#
# Linear solver (1DMC7469__system-execute), solution time 3.046438e-02 (secs)
# Time Integration
# 	2nd order:                 5Q9T0C41__integrand -    0.0183 [min] /    0.0183 [max] (secs)
# Time Integration - 0.0183539 [min] / 0.0183539 [max] (secs)
# Time Integration
# 	2nd order:                 ZH8F1NRD__integrand -    0.0000 [min] /    0.0000 [max] (secs)
# Time Integration - 5.6336e-05 [min] / 5.6336e-05 [max] (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"
# Step:    21 Model Time: 4920.7 year dt:    0.0 second (2025-05-21 14:06:06)
# Linear solver (1DMC7469__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001474 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0006308 secs / 1 its
#   Pressure Solve:         = 0.005053 secs / 5 its
#   Final V Solve:          = 0.0008527 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.032365 seconds
#
# Linear solver (1DMC7469__system-execute), solution time 3.257750e-02 (secs)
# Time Integration
# 	2nd order:                 5Q9T0C41__integrand -    0.0182 [min] /    0.0182 [max] (secs)
# Time Integration - 0.0182526 [min] / 0.0182526 [max] (secs)
# Time Integration
# 	2nd order:                 ZH8F1NRD__integrand -    0.0000 [min] /    0.0000 [max] (secs)
# Time Integration - 5.3933e-05 [min] / 5.3933e-05 [max] (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"
# Step:    22 Model Time: 5166.7 year dt:  246.0 year (2025-05-21 14:06:06)
# Linear solver (1DMC7469__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001510 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0006101 secs / 1 its
#   Pressure Solve:         = 0.003066 secs / 5 its
#   Final V Solve:          = 0.0005043 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.027188 seconds
#
# Linear solver (1DMC7469__system-execute), solution time 2.737347e-02 (secs)
# Time Integration
# 	2nd order:                 5Q9T0C41__integrand -    0.0182 [min] /    0.0182 [max] (secs)
# Time Integration - 0.0182554 [min] / 0.0182554 [max] (secs)
# Time Integration
# 	2nd order:                 ZH8F1NRD__integrand -    0.0000 [min] /    0.0000 [max] (secs)
# Time Integration - 5.591e-05 [min] / 5.591e-05 [max] (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"
# Step:    23 Model Time: 5412.7 year dt:  246.0 year (2025-05-21 14:06:06)
# Linear solver (1DMC7469__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001472 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.00136 secs / 1 its
#   Pressure Solve:         = 0.005941 secs / 5 its
#   Final V Solve:          = 0.0005123 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.031911 seconds
#
# Linear solver (1DMC7469__system-execute), solution time 3.209926e-02 (secs)
# Time Integration
# 	2nd order:                 5Q9T0C41__integrand -    0.0182 [min] /    0.0182 [max] (secs)
# Time Integration - 0.0182223 [min] / 0.0182223 [max] (secs)
# Time Integration
# 	2nd order:                 ZH8F1NRD__integrand -    0.0000 [min] /    0.0000 [max] (secs)
# Time Integration - 4.3762e-05 [min] / 4.3762e-05 [max] (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"
# Step:    24 Model Time: 5658.8 year dt:  246.0 year (2025-05-21 14:06:06)
# Linear solver (1DMC7469__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001498 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.000626 secs / 1 its
#   Pressure Solve:         = 0.003136 secs / 5 its
#   Final V Solve:          = 0.000501 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.029125 seconds
#
# Linear solver (1DMC7469__system-execute), solution time 2.930708e-02 (secs)
# Time Integration
# 	2nd order:                 5Q9T0C41__integrand -    0.0199 [min] /    0.0199 [max] (secs)
# Time Integration - 0.0199026 [min] / 0.0199026 [max] (secs)
# Time Integration
# 	2nd order:                 ZH8F1NRD__integrand -    0.0000 [min] /    0.0000 [max] (secs)
# Time Integration - 5.3701e-05 [min] / 5.3701e-05 [max] (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"
# Step:    25 Model Time: 5904.8 year dt:  246.0 year (2025-05-21 14:06:07)
# Linear solver (1DMC7469__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001452 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0005942 secs / 1 its
#   Pressure Solve:         = 0.005164 secs / 5 its
#   Final V Solve:          = 0.0009047 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.030052 seconds
#
# Linear solver (1DMC7469__system-execute), solution time 3.026164e-02 (secs)
# Time Integration
# 	2nd order:                 5Q9T0C41__integrand -    0.0202 [min] /    0.0202 [max] (secs)
# Time Integration - 0.020231 [min] / 0.020231 [max] (secs)
# Time Integration
# 	2nd order:                 ZH8F1NRD__integrand -    0.0000 [min] /    0.0000 [max] (secs)
# Time Integration - 5.7966e-05 [min] / 5.7966e-05 [max] (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"
# Step:    26 Model Time: 6150.8 year dt:  246.0 year (2025-05-21 14:06:07)
# Linear solver (1DMC7469__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001541 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0006143 secs / 1 its
#   Pressure Solve:         = 0.004023 secs / 5 its
#   Final V Solve:          = 0.001001 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.029341 seconds
#
# Linear solver (1DMC7469__system-execute), solution time 2.961996e-02 (secs)
# Time Integration
# 	2nd order:                 5Q9T0C41__integrand -    0.0197 [min] /    0.0197 [max] (secs)
# Time Integration - 0.0197218 [min] / 0.0197218 [max] (secs)
# Time Integration
# 	2nd order:                 ZH8F1NRD__integrand -    0.0000 [min] /    0.0000 [max] (secs)
# Time Integration - 5.3309e-05 [min] / 5.3309e-05 [max] (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"
# Step:    27 Model Time: 6150.8 year dt:    0.0 second (2025-05-21 14:06:07)
# Linear solver (1DMC7469__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001648 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0006146 secs / 1 its
#   Pressure Solve:         = 0.003358 secs / 5 its
#   Final V Solve:          = 0.0005782 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.029663 seconds
#
# Linear solver (1DMC7469__system-execute), solution time 2.985912e-02 (secs)
# Time Integration
# 	2nd order:                 5Q9T0C41__integrand -    0.0186 [min] /    0.0186 [max] (secs)
# Time Integration - 0.0186167 [min] / 0.0186167 [max] (secs)
# Time Integration
# 	2nd order:                 ZH8F1NRD__integrand -    0.0000 [min] /    0.0000 [max] (secs)
# Time Integration - 5.3606e-05 [min] / 5.3606e-05 [max] (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"
# Step:    28 Model Time: 6396.9 year dt:  246.0 year (2025-05-21 14:06:08)
# Linear solver (1DMC7469__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001511 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.001228 secs / 1 its
#   Pressure Solve:         = 0.006026 secs / 5 its
#   Final V Solve:          = 0.00148 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.060246 seconds
#
# Linear solver (1DMC7469__system-execute), solution time 6.049424e-02 (secs)
# Time Integration
# 	2nd order:                 5Q9T0C41__integrand -    0.0182 [min] /    0.0182 [max] (secs)
# Time Integration - 0.0182512 [min] / 0.0182512 [max] (secs)
# Time Integration
# 	2nd order:                 ZH8F1NRD__integrand -    0.0000 [min] /    0.0000 [max] (secs)
# Time Integration - 5.5452e-05 [min] / 5.5452e-05 [max] (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"
# Step:    29 Model Time: 6642.9 year dt:  246.0 year (2025-05-21 14:06:08)
# Linear solver (1DMC7469__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.002481 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.00108 secs / 1 its
#   Pressure Solve:         = 0.005299 secs / 5 its
#   Final V Solve:          = 0.0008736 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.036862 seconds
#
# Linear solver (1DMC7469__system-execute), solution time 3.708484e-02 (secs)
# Time Integration
# 	2nd order:                 5Q9T0C41__integrand -    0.0204 [min] /    0.0204 [max] (secs)
# Time Integration - 0.0203789 [min] / 0.0203789 [max] (secs)
# Time Integration
# 	2nd order:                 ZH8F1NRD__integrand -    0.0000 [min] /    0.0000 [max] (secs)
# Time Integration - 5.8167e-05 [min] / 5.8167e-05 [max] (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"
# Step:    30 Model Time: 6888.9 year dt:  246.0 year (2025-05-21 14:06:08)
# Linear solver (1DMC7469__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001491 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.000616 secs / 1 its
#   Pressure Solve:         = 0.003538 secs / 5 its
#   Final V Solve:          = 0.0005784 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.026563 seconds
#
# Linear solver (1DMC7469__system-execute), solution time 2.678052e-02 (secs)
# Time Integration
# 	2nd order:                 5Q9T0C41__integrand -    0.0197 [min] /    0.0197 [max] (secs)
# Time Integration - 0.0197732 [min] / 0.0197732 [max] (secs)
# Time Integration
# 	2nd order:                 ZH8F1NRD__integrand -    0.0000 [min] /    0.0000 [max] (secs)
# Time Integration - 4.6176e-05 [min] / 4.6176e-05 [max] (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"
# Step:    31 Model Time: 7135.0 year dt:  246.0 year (2025-05-21 14:06:09)
# Linear solver (1DMC7469__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001442 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.001199 secs / 1 its
#   Pressure Solve:         = 0.005617 secs / 5 its
#   Final V Solve:          = 0.0009622 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.034198 seconds
#
# Linear solver (1DMC7469__system-execute), solution time 3.440278e-02 (secs)
# Time Integration
# 	2nd order:                 5Q9T0C41__integrand -    0.0205 [min] /    0.0205 [max] (secs)
# Time Integration - 0.0205085 [min] / 0.0205085 [max] (secs)
# Time Integration
# 	2nd order:                 ZH8F1NRD__integrand -    0.0000 [min] /    0.0000 [max] (secs)
# Time Integration - 6.1185e-05 [min] / 6.1185e-05 [max] (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"
# Step:    32 Model Time: 7381.0 year dt:  246.0 year (2025-05-21 14:06:09)
# Linear solver (1DMC7469__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001534 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.001176 secs / 1 its
#   Pressure Solve:         = 0.004792 secs / 5 its
#   Final V Solve:          = 0.0008917 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.032779 seconds
#
# Linear solver (1DMC7469__system-execute), solution time 3.303936e-02 (secs)
# Time Integration
# 	2nd order:                 5Q9T0C41__integrand -    0.0208 [min] /    0.0208 [max] (secs)
# Time Integration - 0.020782 [min] / 0.020782 [max] (secs)
# Time Integration
# 	2nd order:                 ZH8F1NRD__integrand -    0.0000 [min] /    0.0000 [max] (secs)
# Time Integration - 6.1441e-05 [min] / 6.1441e-05 [max] (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"
# Step:    33 Model Time: 7381.0 year dt:    0.0 second (2025-05-21 14:06:09)
# Linear solver (1DMC7469__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001839 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0009508 secs / 1 its
#   Pressure Solve:         = 0.005498 secs / 5 its
#   Final V Solve:          = 0.0005668 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.034000 seconds
#
# Linear solver (1DMC7469__system-execute), solution time 3.421557e-02 (secs)
# Time Integration
# 	2nd order:                 5Q9T0C41__integrand -    0.0184 [min] /    0.0184 [max] (secs)
# Time Integration - 0.0183824 [min] / 0.0183824 [max] (secs)
# Time Integration
# 	2nd order:                 ZH8F1NRD__integrand -    0.0000 [min] /    0.0000 [max] (secs)
# Time Integration - 5.4713e-05 [min] / 5.4713e-05 [max] (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"
# Step:    34 Model Time: 7627.0 year dt:  246.0 year (2025-05-21 14:06:10)
# Linear solver (1DMC7469__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001479 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0006381 secs / 1 its
#   Pressure Solve:         = 0.003181 secs / 5 its
#   Final V Solve:          = 0.0009954 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.028003 seconds
#
# Linear solver (1DMC7469__system-execute), solution time 2.820492e-02 (secs)
# Time Integration
# 	2nd order:                 5Q9T0C41__integrand -    0.0199 [min] /    0.0199 [max] (secs)
# Time Integration - 0.019876 [min] / 0.019876 [max] (secs)
# Time Integration
# 	2nd order:                 ZH8F1NRD__integrand -    0.0000 [min] /    0.0000 [max] (secs)
# Time Integration - 4.848e-05 [min] / 4.848e-05 [max] (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"
# Step:    35 Model Time: 7873.1 year dt:  246.0 year (2025-05-21 14:06:10)
# Linear solver (1DMC7469__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001610 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.001039 secs / 1 its
#   Pressure Solve:         = 0.004466 secs / 5 its
#   Final V Solve:          = 0.0005372 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.031890 seconds
#
# Linear solver (1DMC7469__system-execute), solution time 3.210325e-02 (secs)
# Time Integration
# 	2nd order:                 5Q9T0C41__integrand -    0.0184 [min] /    0.0184 [max] (secs)
# Time Integration - 0.0183923 [min] / 0.0183923 [max] (secs)
# Time Integration
# 	2nd order:                 ZH8F1NRD__integrand -    0.0000 [min] /    0.0000 [max] (secs)
# Time Integration - 6.1139e-05 [min] / 6.1139e-05 [max] (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"
# Step:    36 Model Time: 8119.1 year dt:  246.0 year (2025-05-21 14:06:10)
# Linear solver (1DMC7469__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001493 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.001031 secs / 1 its
#   Pressure Solve:         = 0.004029 secs / 5 its
#   Final V Solve:          = 0.0005067 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.030499 seconds
#
# Linear solver (1DMC7469__system-execute), solution time 3.070983e-02 (secs)
# Time Integration
# 	2nd order:                 5Q9T0C41__integrand -    0.0203 [min] /    0.0203 [max] (secs)
# Time Integration - 0.0203611 [min] / 0.0203611 [max] (secs)
# Time Integration
# 	2nd order:                 ZH8F1NRD__integrand -    0.0000 [min] /    0.0000 [max] (secs)
# Time Integration - 5.9681e-05 [min] / 5.9681e-05 [max] (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"
# Step:    37 Model Time: 8365.1 year dt:  246.0 year (2025-05-21 14:06:10)
# Linear solver (1DMC7469__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001762 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.001226 secs / 1 its
#   Pressure Solve:         = 0.006097 secs / 5 its
#   Final V Solve:          = 0.001048 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.034175 seconds
#
# Linear solver (1DMC7469__system-execute), solution time 3.440961e-02 (secs)
# Time Integration
# 	2nd order:                 5Q9T0C41__integrand -    0.0196 [min] /    0.0196 [max] (secs)
# Time Integration - 0.0196015 [min] / 0.0196015 [max] (secs)
# Time Integration
# 	2nd order:                 ZH8F1NRD__integrand -    0.0000 [min] /    0.0000 [max] (secs)
# Time Integration - 5.9302e-05 [min] / 5.9302e-05 [max] (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"
# Step:    38 Model Time: 8611.2 year dt:  246.0 year (2025-05-21 14:06:11)
# Linear solver (1DMC7469__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001543 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.001294 secs / 1 its
#   Pressure Solve:         = 0.005307 secs / 5 its
#   Final V Solve:          = 0.0009398 secs / 1 its
#
# ...
#
#   Total BSSCR Linear solve time: 0.032388 seconds
#
# Linear solver (1DMC7469__system-execute), solution time 3.267444e-02 (secs)
# Time Integration
# 	2nd order:                 5Q9T0C41__integrand -    0.0210 [min] /    0.0210 [max] (secs)
# Time Integration - 0.0210397 [min] / 0.0210397 [max] (secs)
# Time Integration
# 	2nd order:                 ZH8F1NRD__integrand -    0.0000 [min] /    0.0000 [max] (secs)
# Time Integration - 6.219e-05 [min] / 6.219e-05 [max] (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"
# Step:   395 Model Time: 95707.0 year dt:  246.0 year (2025-05-21 14:08:13)
# Linear solver (1DMC7469__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001680 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0006353 secs / 1 its
#   Pressure Solve:         = 0.005832 secs / 5 its
#   Final V Solve:          = 0.001164 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.030882 seconds
#
# Linear solver (1DMC7469__system-execute), solution time 3.118498e-02 (secs)
# Time Integration
# 	2nd order:                 5Q9T0C41__integrand -    0.0219 [min] /    0.0219 [max] (secs)
# Time Integration - 0.0219242 [min] / 0.0219242 [max] (secs)
# Time Integration
# 	2nd order:                 ZH8F1NRD__integrand -    0.0000 [min] /    0.0000 [max] (secs)
# Time Integration - 5.8305e-05 [min] / 5.8305e-05 [max] (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"
# Step:   396 Model Time: 95953.0 year dt:  246.0 year (2025-05-21 14:08:14)
# Linear solver (1DMC7469__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.002528 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.001272 secs / 1 its
#   Pressure Solve:         = 0.005484 secs / 5 its
#   Final V Solve:          = 0.0006383 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.036525 seconds
#
# Linear solver (1DMC7469__system-execute), solution time 3.688498e-02 (secs)
# Time Integration
# 	2nd order:                 5Q9T0C41__integrand -    0.0234 [min] /    0.0234 [max] (secs)
# Time Integration - 0.0234583 [min] / 0.0234583 [max] (secs)
# Time Integration
# 	2nd order:                 ZH8F1NRD__integrand -    0.0000 [min] /    0.0000 [max] (secs)
# Time Integration - 6.3873e-05 [min] / 6.3873e-05 [max] (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"
# Step:   397 Model Time: 96199.1 year dt:  246.0 year (2025-05-21 14:08:14)
# Linear solver (1DMC7469__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001613 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0006449 secs / 1 its
#   Pressure Solve:         = 0.003018 secs / 5 its
#   Final V Solve:          = 0.0005166 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.030225 seconds
#
# Linear solver (1DMC7469__system-execute), solution time 3.047655e-02 (secs)
# Time Integration
# 	2nd order:                 5Q9T0C41__integrand -    0.0241 [min] /    0.0241 [max] (secs)
# Time Integration - 0.0241225 [min] / 0.0241225 [max] (secs)
# Time Integration
# 	2nd order:                 ZH8F1NRD__integrand -    0.0000 [min] /    0.0000 [max] (secs)
# Time Integration - 5.2957e-05 [min] / 5.2957e-05 [max] (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"
# Step:   398 Model Time: 96445.1 year dt:  246.0 year (2025-05-21 14:08:15)
# Linear solver (1DMC7469__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001787 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.001043 secs / 1 its
#   Pressure Solve:         = 0.003123 secs / 5 its
#   Final V Solve:          = 0.0008342 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.032530 seconds
#
# Linear solver (1DMC7469__system-execute), solution time 3.284875e-02 (secs)
# Time Integration
# 	2nd order:                 5Q9T0C41__integrand -    0.0226 [min] /    0.0226 [max] (secs)
# Time Integration - 0.0226576 [min] / 0.0226576 [max] (secs)
# Time Integration
# 	2nd order:                 ZH8F1NRD__integrand -    0.0000 [min] /    0.0000 [max] (secs)
# Time Integration - 5.7939e-05 [min] / 5.7939e-05 [max] (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"
# Step:   399 Model Time: 96691.1 year dt:  246.0 year (2025-05-21 14:08:15)
# Linear solver (1DMC7469__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001795 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0007052 secs / 1 its
#   Pressure Solve:         = 0.002992 secs / 5 its
#   Final V Solve:          = 0.0005217 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.029699 seconds
#
# Linear solver (1DMC7469__system-execute), solution time 2.997127e-02 (secs)
# Time Integration
# 	2nd order:                 5Q9T0C41__integrand -    0.0224 [min] /    0.0224 [max] (secs)
# Time Integration - 0.0224306 [min] / 0.0224306 [max] (secs)
# Time Integration
# 	2nd order:                 ZH8F1NRD__integrand -    0.0000 [min] /    0.0000 [max] (secs)
# Time Integration - 6.1931e-05 [min] / 6.1931e-05 [max] (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"
# Step:   400 Model Time: 96937.2 year dt:  246.0 year (2025-05-21 14:08:15)
# Linear solver (1DMC7469__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001757 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.001164 secs / 1 its
#   Pressure Solve:         = 0.00436 secs / 5 its
#   Final V Solve:          = 0.001022 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.033364 seconds
#
# Linear solver (1DMC7469__system-execute), solution time 3.365375e-02 (secs)
# Time Integration
# 	2nd order:                 5Q9T0C41__integrand -    0.0234 [min] /    0.0234 [max] (secs)
# Time Integration - 0.0234513 [min] / 0.0234513 [max] (secs)
# Time Integration
# 	2nd order:                 ZH8F1NRD__integrand -    0.0000 [min] /    0.0000 [max] (secs)
# Time Integration - 5.5386e-05 [min] / 5.5386e-05 [max] (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"
# Step:   401 Model Time: 97183.2 year dt:  246.0 year (2025-05-21 14:08:16)
# Linear solver (1DMC7469__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001759 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0006415 secs / 1 its
#   Pressure Solve:         = 0.003199 secs / 5 its
#   Final V Solve:          = 0.0006857 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.030963 seconds
#
# Linear solver (1DMC7469__system-execute), solution time 3.127046e-02 (secs)
# Time Integration
# 	2nd order:                 5Q9T0C41__integrand -    0.0220 [min] /    0.0220 [max] (secs)
# Time Integration - 0.0219968 [min] / 0.0219968 [max] (secs)
# Time Integration
# 	2nd order:                 ZH8F1NRD__integrand -    0.0000 [min] /    0.0000 [max] (secs)
# Time Integration - 6.0613e-05 [min] / 6.0613e-05 [max] (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"
# Step:   402 Model Time: 97429.2 year dt:  246.0 year (2025-05-21 14:08:16)
# Linear solver (1DMC7469__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001723 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.001136 secs / 1 its
#   Pressure Solve:         = 0.005448 secs / 5 its
#   Final V Solve:          = 0.0009232 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.035639 seconds
#
# Linear solver (1DMC7469__system-execute), solution time 3.592474e-02 (secs)
# Time Integration
# 	2nd order:                 5Q9T0C41__integrand -    0.0239 [min] /    0.0239 [max] (secs)
# Time Integration - 0.0239631 [min] / 0.0239631 [max] (secs)
# Time Integration
# 	2nd order:                 ZH8F1NRD__integrand -    0.0000 [min] /    0.0000 [max] (secs)
# Time Integration - 6.1912e-05 [min] / 6.1912e-05 [max] (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"
# Step:   403 Model Time: 97675.3 year dt:  246.0 year (2025-05-21 14:08:16)
# Linear solver (1DMC7469__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001571 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0007588 secs / 1 its
#   Pressure Solve:         = 0.005797 secs / 5 its
#   Final V Solve:          = 0.00119 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.032803 seconds
#
# Linear solver (1DMC7469__system-execute), solution time 3.307553e-02 (secs)
# Time Integration
# 	2nd order:                 5Q9T0C41__integrand -    0.0221 [min] /    0.0221 [max] (secs)
# Time Integration - 0.0221231 [min] / 0.0221231 [max] (secs)
# Time Integration
# 	2nd order:                 ZH8F1NRD__integrand -    0.0000 [min] /    0.0000 [max] (secs)
# Time Integration - 5.6488e-05 [min] / 5.6488e-05 [max] (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"
# Step:   404 Model Time: 97921.3 year dt:  246.0 year (2025-05-21 14:08:17)
# Linear solver (1DMC7469__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001615 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0006088 secs / 1 its
#   Pressure Solve:         = 0.004638 secs / 5 its
#   Final V Solve:          = 0.0009563 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.030010 seconds
#
# Linear solver (1DMC7469__system-execute), solution time 3.029472e-02 (secs)
# Time Integration
# 	2nd order:                 5Q9T0C41__integrand -    0.0222 [min] /    0.0222 [max] (secs)
# Time Integration - 0.022208 [min] / 0.022208 [max] (secs)
# Time Integration
# 	2nd order:                 ZH8F1NRD__integrand -    0.0000 [min] /    0.0000 [max] (secs)
# Time Integration - 5.8456e-05 [min] / 5.8456e-05 [max] (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"
# Step:   405 Model Time: 98167.3 year dt:  246.0 year (2025-05-21 14:08:17)
# Linear solver (1DMC7469__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001679 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0006279 secs / 1 its
#   Pressure Solve:         = 0.003044 secs / 5 its
#   Final V Solve:          = 0.0004852 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.029304 seconds
#
# Linear solver (1DMC7469__system-execute), solution time 2.955520e-02 (secs)
# Time Integration
# 	2nd order:                 5Q9T0C41__integrand -    0.0219 [min] /    0.0219 [max] (secs)
# Time Integration - 0.0219509 [min] / 0.0219509 [max] (secs)
# Time Integration
# 	2nd order:                 ZH8F1NRD__integrand -    0.0000 [min] /    0.0000 [max] (secs)
# Time Integration - 5.9221e-05 [min] / 5.9221e-05 [max] (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"
# Step:   406 Model Time: 98413.4 year dt:  246.0 year (2025-05-21 14:08:18)
# Linear solver (1DMC7469__system-execute)
#
# BSSCR -- Block Stokes Schur Compliment Reduction Solver
#
#
# -----  K2_GMG  ------
#
# AUGMENTED LAGRANGIAN K2 METHOD - Penalty = 1000.000000
#
#
# 	* K+p*K2 in time: 0.001481 seconds
#
#   Setting schur_pc to "gkgdiag"
#
#
# SCR Solver Summary:
#
#   RHS V Solve:            = 0.0006412 secs / 1 its
#   Pressure Solve:         = 0.003021 secs / 5 its
#   Final V Solve:          = 0.0004823 secs / 1 its
#
#   Total BSSCR Linear solve time: 0.028105 seconds
#
# Linear solver (1DMC7469__system-execute), solution time 2.834605e-02 (secs)
# Time Integration
# 	2nd order:                 5Q9T0C41__integrand -    0.0226 [min] /    0.0226 [max] (secs)
# Time Integration - 0.0226238 [min] / 0.0226238 [max] (secs)
# Time Integration
# 	2nd order:                 ZH8F1NRD__integrand -    0.0000 [min] /    0.0000 [max] (secs)
# Time Integration - 5.8206e-05 [min] / 5.8206e-05 [max] (secs)
# In func WeightsCalculator_CalculateAll(): for swarm "HXGDDD9T__swarm"
# 	done 33% (1000 cells)...
# 	done 67% (2000 cells)...
# 	done 100% (3000 cells)...
# WeightsCalculator_CalculateAll(): finished update of weights for swarm "HXGDDD9T__swarm"
# Step:   407 Model Time: 98413.4 year dt:    0.0 second (2025-05-21 14:08:18)
# 1
